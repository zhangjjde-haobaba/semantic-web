# %%
import pandas as pd

# %% [markdown]
# ## soft matching

# %%
# import data
df_applicants = pd.read_excel('applicants.xlsx')
df_roles = pd.read_excel("roles.xlsx")

# %%
from datetime import datetime, timedelta
from pytz import timezone
# Hard matched package
def check_location(applicant_addr, project_location):
    location_split = project_location.split(";")
    location_split = [location.strip() for location in location_split]
    return applicant_addr in location_split

def check_availability(talent_date, project_date):
    return talent_date <= project_date

def check_skills(talent_skills_str, project_skills_str):
    talent_skills = talent_skills_str.split(",")
    talent_skills = [talent_skill.strip() for talent_skill in talent_skills]
    project_skills = project_skills_str.split(",")
    project_skills = [skill.strip() for skill in project_skills]
    return all(elem in talent_skills for elem in project_skills)

def check_working_hours(talent_hours, project_hours):
    return talent_hours >= project_hours

def check_languages(talent_languages_str, project_languages_str):
    talent_languages = talent_languages_str.split(",")
    talent_languages = [talent_language.strip() for talent_language in talent_languages]
    project_languages = project_languages_str.split(",")
    project_languages = [project_language.strip() for project_language in project_languages]
    return all(item in talent_languages for item in project_languages)

def check_overlap_time(talent_timezone, talent_working_hours, project_timezone, project_working_hours, overlap_time):
  # niform time zone
  applicant_timezone = 'Etc/' + talent_timezone
  role_timezone = 'Etc/' + project_timezone

  applicant_timezone = timezone(applicant_timezone)
  role_timezone = timezone(role_timezone)


  applicants_start_time_str, applicants_end_time_str = talent_working_hours.split(" - ")
  roles_start_time_str, roles_end_time_str = project_working_hours.split(" - ")

  applicant_start_time = applicant_timezone.localize(datetime.strptime(applicants_start_time_str, "%H:%M"))
  applicant_end_time = applicant_timezone.localize(datetime.strptime(applicants_end_time_str, "%H:%M"))

  role_start_time = role_timezone.localize(datetime.strptime(roles_start_time_str, "%H:%M"))
  role_end_time = role_timezone.localize(datetime.strptime(roles_end_time_str, "%H:%M"))


  overlap_start = max(applicant_start_time, role_start_time)
  overlap_end = min(applicant_end_time, role_end_time)

  overlap_duration = overlap_end - overlap_start
  return overlap_duration.seconds/3600 >= int(overlap_time)

# %%
# importance of feature

Tools_importance = 0.5
years_importance = 0.75
hourlyRate_importance = 0.5
preferredSkills_importance = 0.5
industry_importance = 0.5
text_importance = 0.25

# weight of feature
Tools_w = 0.5/(Tools_importance + years_importance + hourlyRate_importance + preferredSkills_importance + industry_importance + text_importance)
years_w = 0.75/(Tools_importance + years_importance + hourlyRate_importance + preferredSkills_importance + industry_importance + text_importance)
hourlyRate_w = 0.5/(Tools_importance + years_importance + hourlyRate_importance + preferredSkills_importance + industry_importance + text_importance)
preferredSkills_w = 0.5/(Tools_importance + years_importance + hourlyRate_importance + preferredSkills_importance + industry_importance + text_importance)
industry_w = 0.5/(Tools_importance + years_importance + hourlyRate_importance + preferredSkills_importance + industry_importance + text_importance)
text_w = 0.25/(Tools_importance + years_importance + hourlyRate_importance + preferredSkills_importance + industry_importance + text_importance)

# %%
# Traverse the applicants data
roles_info = {}
for _, applicant in df_applicants.iterrows():

  # Initialize the matching score
  roles_list = []
  matches = []
  for _, project in df_roles.iterrows():
    if (
      check_location(applicant['Location'], project['Location']) and
      check_availability(applicant['Availability (Available from date)'], project['Availability Date']) and
      check_skills(applicant['Skills'], project['Required Skills']) and
      check_working_hours(applicant['Hours to commit'], project['Minimum Available Hours per Week']) and
      check_languages(applicant['Languages'], project['Language']) and
      check_overlap_time(applicant['Time Zone'], applicant['Working Hours'], project['Time Zone'], project['Working Hours'], project['Overlap Time'])
    ):
      roles_detail = []
      project_experience = project['Years of Experience']
      project_rate = project['Hourly Rate']
      project_tools = project['Tools'].split(', ')
      project_skills = project['Preferred Skills'].split(', ')
      match_score = 0.0
      # Check that employees have all the skills, tools, and experience required for the position
      count_skills = sum(1 for item in project_skills if item in applicant['Skills'])
      count_tools = sum(1 for item in project_skills if item in applicant['Tools'])
      count_ex = 1 if project_experience <= applicant['Years of Professional Experience'] else 0
      count_rate = 1 if project_rate >= applicant['Hourly Rate($)'] else 0
      # print(applicant['Work Experience (Title, Company, Years, Industry)'].split(';')[3])
      cont_industry = 1 if project['industry'] == applicant['Work Experience (Title, Company, Years, Industry)'].split(';')[3] else 0

      # The match score
      match_score = count_skills / len(project_skills) * preferredSkills_w + count_tools / len(project_tools) * Tools_w + count_ex * years_w + count_rate * hourlyRate_w
      roles_detail.append(project['Project ID'])
      roles_detail.append(project['Role Name'])
      roles_detail.append(match_score)
      # roles_list.append(str(project['Project ID'])+ ',' + project['Role Name'] + ',' + str(match_score))
      roles_list.append(roles_detail)
      sorted_list = sorted(roles_list, key=lambda x: x[2], reverse=True)
  # add matching results to the list
  roles_info[applicant['UID']] = sorted_list
roles_info
# Out:
# {'c059eaf0-9eec-4173-aa9f-c65ab442b7fa': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [13844, 'Business Development Manager', 0.5833333333333333],
#   [60137, 'Technical Project Manager', 0.5277777777777778],
#   [75262, 'Data Engineer', 0.5277777777777778],
#   [90991, 'Service/Business Designer', 0.41666666666666663],
#   [13844, 'Cloud Expert', 0.3611111111111111]],
#  'd1d1563e-9bd4-4ca4-9506-85a00aa4bc28': [[13844,
#    'Product Owner',
#    0.41666666666666663],
#   [75262, 'Data Engineer', 0.41666666666666663],
#   [71893, 'Networking/Infrastructure Engineer', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [97963, 'Community Manager', 0.2777777777777778],
#   [97963, 'Motion Graphic Designer', 0.2777777777777778],
#   [90991, 'Chief of Staff', 0.2777777777777778],
#   [82785, 'Security Engineer', 0.16666666666666666],
#   [82785, 'Project Manager', 0.1111111111111111]],
#  '451572c0-68fa-4cd1-b26c-dc8d3f26716b': [[29145,
#    'Product Designer',
#    0.5277777777777778],
#   [29145, 'Game Designer', 0.41666666666666663]],
#  '630d751e-c122-4c15-979b-41379019d236': [[97963,
#    'Business Development Manager',
#    0.16666666666666666]],
#  'fe3c3351-1cd2-4ff3-b053-21cec5999c40': [[85932,
#    'Service/Business Designer',
#    0.5833333333333333],
#   [97963, 'Business Development Manager', 0.41666666666666663]],
#  '61db3452-3cef-4437-94b4-181415738d0f': [[29145,
#    'Algorithms Engineer',
#    0.5833333333333333],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [97963, 'Business Development Manager', 0.16666666666666666],
#   [71893, 'Online Marketing Expert', 0.16666666666666666],
#   [90991, 'Risk & Compliance Consultant', 0.16666666666666666]],
#  '73b37a1d-68c4-4b57-bda1-e5e6486c3eb3': [[29145,
#    'Algorithms Engineer',
#    0.5833333333333333],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [97963, 'Business Development Manager', 0.16666666666666666],
#   [71893, 'Online Marketing Expert', 0.16666666666666666],
#   [90991, 'Risk & Compliance Consultant', 0.16666666666666666]],
#  '6f815298-3f7e-4f8b-bbed-b52b85dfd57d': [[60137,
#    'Data Architect',
#    0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5277777777777778],
#   [13844, 'Cloud Expert', 0.41666666666666663],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [60137, 'Technical Project Manager', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333]],
#  'a88b140f-388b-4820-a01d-ac42d27e9b81': [[48682,
#    'QA Engineer',
#    0.5833333333333333],
#   [90991, 'Chief of Staff', 0.5833333333333333],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [75262, 'Data Engineer', 0.41666666666666663],
#   [82785, 'Security Engineer', 0.41666666666666663],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.16666666666666666]],
#  '74558e1e-34f5-461a-a659-c36667ae455e': [[82785,
#    'HR Officer',
#    0.16666666666666666]],
#  'ca1a101f-4f89-4e16-8c8e-a57afd67a67f': [[90991,
#    'Chief of Staff',
#    0.5833333333333333],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [75262, 'Data Engineer', 0.41666666666666663],
#   [82785, 'Security Engineer', 0.41666666666666663]],
#  '3217a770-c9d7-41f3-8803-cfa670379b40': [[90991,
#    'Chief of Staff',
#    0.5833333333333333],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [75262, 'Data Engineer', 0.41666666666666663],
#   [82785, 'Security Engineer', 0.41666666666666663]],
#  '41cfbb02-1e7d-46c3-bdff-1e38248bd331': [[85932,
#    'Software Architect',
#    0.5833333333333333],
#   [29145, 'Game Designer', 0.41666666666666663],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [97963, 'Community Manager', 0.3333333333333333],
#   [97963, 'Motion Graphic Designer', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Networking/Infrastructure Engineer', 0.3333333333333333],
#   [71893, 'Brand Expert', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [85932, 'Service/Business Designer', 0.3333333333333333],
#   [75262, 'Strategy Consultant', 0.3333333333333333],
#   [75262, 'Motion Graphic Designer', 0.3333333333333333],
#   [90991, 'Chief of Staff', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [82785, 'CX / Business Designer', 0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333],
#   [29145, 'Brand Designer', 0.3333333333333333],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [97963, 'Business Development Manager', 0.16666666666666666],
#   [97963, 'People & Culture Manager', 0.16666666666666666],
#   [13844, 'Product Owner', 0.16666666666666666],
#   [13844, 'Cloud Architect', 0.16666666666666666],
#   [85932, 'User Acquisition Manager', 0.16666666666666666],
#   [82785, 'Project Manager', 0.16666666666666666]],
#  '1dc0893e-41ed-462f-97f6-0a9a4a7a6eb7': [[85932,
#    'Software Architect',
#    0.5833333333333333],
#   [29145, 'Game Designer', 0.41666666666666663],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [97963, 'Community Manager', 0.3333333333333333],
#   [97963, 'Motion Graphic Designer', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Networking/Infrastructure Engineer', 0.3333333333333333],
#   [71893, 'Brand Expert', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [85932, 'Service/Business Designer', 0.3333333333333333],
#   [75262, 'Strategy Consultant', 0.3333333333333333],
#   [75262, 'Motion Graphic Designer', 0.3333333333333333],
#   [90991, 'Chief of Staff', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [82785, 'CX / Business Designer', 0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333],
#   [29145, 'Brand Designer', 0.3333333333333333],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [97963, 'Business Development Manager', 0.16666666666666666],
#   [97963, 'People & Culture Manager', 0.16666666666666666],
#   [13844, 'Product Owner', 0.16666666666666666],
#   [13844, 'Cloud Architect', 0.16666666666666666],
#   [85932, 'User Acquisition Manager', 0.16666666666666666],
#   [82785, 'Project Manager', 0.16666666666666666]],
#  'ee7d8ae9-d66c-41fb-830d-1c37eade010c': [[97963,
#    'Motion Graphic Designer',
#    0.2777777777777778]],
#  'ffe84a3b-abbf-479b-9c65-508df6f7c016': [[97963,
#    'Motion Graphic Designer',
#    0.2777777777777778]],
#  '72be3174-b550-4c1c-87e6-4dd20feecaff': [[97963,
#    'Motion Graphic Designer',
#    0.2777777777777778]],
#  '6fb98948-4513-45c1-9a6f-9a0f8e89139b': [[60137,
#    'Crypto / Web 3.0 Engineer',
#    0.5833333333333333],
#   [97963, 'Community Manager', 0.5277777777777778]],
#  '0bb60dd9-0fcd-4052-915e-cfc929fd00a9': [[60137,
#    'Data Architect',
#    0.5277777777777778]],
#  '782a1212-c7ab-4ce3-a934-2f4614e7bd22': [[71893,
#    'Content Editor',
#    0.5833333333333333],
#   [75262, 'Data Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [82785, 'Project Manager', 0.3611111111111111]],
#  '91e84318-d61e-4bb2-8c38-2691fdf33388': [[71893,
#    'Content Editor',
#    0.5833333333333333],
#   [75262, 'Data Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [82785, 'Project Manager', 0.3611111111111111]],
#  '3bfc2f17-b4cb-43f7-9096-954f80c0e7a0': [[60137,
#    'Crypto / Web 3.0 Engineer',
#    0.5833333333333333],
#   [75262, 'Data Engineer', 0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [48682, 'QA Engineer', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Networking/Infrastructure Engineer', 0.3333333333333333],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [90991, 'Chief of Staff', 0.3333333333333333],
#   [90991, 'Scrum Master', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333],
#   [29145, 'Brand Designer', 0.3333333333333333],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [13844, 'Cloud Expert', 0.16666666666666666],
#   [13844, 'Cloud Architect', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.16666666666666666],
#   [75262, 'Strategy Consultant', 0.16666666666666666],
#   [75262, 'Technical Project Manager', 0.16666666666666666],
#   [90991, 'Service/Business Designer', 0.16666666666666666]],
#  'b5db3fb8-4579-4818-a3af-37877fcbc406': [[60137,
#    'Crypto / Web 3.0 Engineer',
#    0.5833333333333333],
#   [75262, 'Data Engineer', 0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [48682, 'QA Engineer', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Networking/Infrastructure Engineer', 0.3333333333333333],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [90991, 'Chief of Staff', 0.3333333333333333],
#   [90991, 'Scrum Master', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333],
#   [29145, 'Brand Designer', 0.3333333333333333],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [13844, 'Cloud Expert', 0.16666666666666666],
#   [13844, 'Cloud Architect', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.16666666666666666],
#   [75262, 'Strategy Consultant', 0.16666666666666666],
#   [75262, 'Technical Project Manager', 0.16666666666666666],
#   [90991, 'Service/Business Designer', 0.16666666666666666]],
#  'ee0ff0c0-0103-4402-925a-2914963fcd0f': [[48682,
#    'Management Consultant',
#    0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.2777777777777778],
#   [71893, 'Online Marketing Expert', 0.2777777777777778],
#   [71893, 'Content Editor', 0.2777777777777778]],
#  'ee8b955b-b764-45ce-98e7-6dfbe865c440': [[90991,
#    'Chief of Staff',
#    0.3333333333333333]],
#  '0e02fa02-e9c5-4cfa-9cd1-994340fb1022': [[90991,
#    'Chief of Staff',
#    0.3333333333333333]],
#  'acbc9092-7be7-40cb-a2a8-6ea98424cf4d': [[60137,
#    'Data Architect',
#    0.5833333333333333],
#   [60137, 'Technical Project Manager', 0.16666666666666666]],
#  '8236d3d8-9564-4a0c-89a3-4d4f527cb258': [[60137,
#    'Data Architect',
#    0.5833333333333333],
#   [60137, 'Technical Project Manager', 0.16666666666666666]],
#  'ee3218b4-a651-4bc8-9230-7d4c39d3be3b': [[60137,
#    'Data Architect',
#    0.5833333333333333],
#   [60137, 'Technical Project Manager', 0.16666666666666666]],
#  '3c4ed91d-7cd6-4c15-a361-bb342760ac86': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [71893, 'Networking/Infrastructure Engineer', 0.5833333333333333],
#   [71893, 'Online Marketing Expert', 0.5833333333333333],
#   [60137, 'Data Architect', 0.5833333333333333],
#   [75262, 'Motion Graphic Designer', 0.5833333333333333],
#   [82785, 'Security Engineer', 0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [13844, 'Cloud Expert', 0.41666666666666663],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [75262, 'Strategy Consultant', 0.41666666666666663],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [29145, 'Brand Designer', 0.3333333333333333],
#   [60137, 'Technical Project Manager', 0.16666666666666666]],
#  '1f49f7fd-fac1-4c0e-acc8-678868569da9': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [90991, 'Service/Business Designer', 0.41666666666666663]],
#  'ac883d3b-d883-4394-b559-04ca95e4b7fe': [[90991,
#    'Chief of Staff',
#    0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333]],
#  '6ea9348c-17fe-48d1-a4b1-b799948a83d4': [[97963,
#    'Community Manager',
#    0.3333333333333333],
#   [97963, 'Motion Graphic Designer', 0.3333333333333333]],
#  'deda4d9c-fe11-4ef4-86a0-985107168458': [[60137,
#    'Technical Project Manager',
#    0.1111111111111111]],
#  '8848c0fc-8f12-4bc5-b795-16be14b9a6e6': [[97963,
#    'Business Development Manager',
#    0.3333333333333333],
#   [85932, 'Service/Business Designer', 0.3333333333333333],
#   [85932, 'Management Consultant', 0.3333333333333333],
#   [97963, 'Community Manager', 0.2777777777777778],
#   [97963, 'Motion Graphic Designer', 0.2777777777777778]],
#  '4c860395-fe6b-49be-a4ac-3ec591f897cb': [[90991,
#    'Chief of Staff',
#    0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333]],
#  'aeaa180c-7984-42ba-a9e2-036a1b2e01ab': [[90991,
#    'Chief of Staff',
#    0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333]],
#  '260ef4e0-4817-415b-9cbe-f8abc6d8802e': [[90991,
#    'Chief of Staff',
#    0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333]],
#  'e9247048-07de-4477-99df-3a6f3a881376': [[48682,
#    'Management Consultant',
#    0.41666666666666663],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [48682, 'QA Engineer', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.2777777777777778],
#   [71893, 'Online Marketing Expert', 0.1111111111111111]],
#  '2d04d111-5bf9-4bc5-a013-e0620b905820': [[75262,
#    'Data Engineer',
#    0.5277777777777778],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [90991, 'Service/Business Designer', 0.16666666666666666]],
#  '4ed64c28-350b-4595-ae16-2a026a475b27': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [13844, 'Business Development Manager', 0.5833333333333333],
#   [71893, 'Brand Expert', 0.5833333333333333],
#   [75262, 'Data Engineer', 0.5277777777777778],
#   [90991, 'Service/Business Designer', 0.41666666666666663],
#   [13844, 'Cloud Expert', 0.3611111111111111],
#   [29145, 'Brand Designer', 0.2777777777777778]],
#  'aa1468ad-644c-4bd4-b012-5046e1d8a2b6': [[85932,
#    'Service/Business Designer',
#    0.5833333333333333],
#   [97963, 'Business Development Manager', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.16666666666666666]],
#  'ce32ab68-a51c-48d5-be0f-a5517ead4c66': [[97963,
#    'Business Development Manager',
#    0.16666666666666666]],
#  '4d81d109-8dfd-472c-8308-fc7812cec1f5': [[60137,
#    'Crypto / Web 3.0 Engineer',
#    0.5833333333333333],
#   [97963, 'Community Manager', 0.3333333333333333],
#   [85932, 'Management Consultant', 0.3333333333333333],
#   [60137, 'Technical Project Manager', 0.16666666666666666]],
#  'cda42d28-f061-4f68-b0ed-c8dd027c6334': [[97963,
#    'Community Manager',
#    0.3333333333333333],
#   [97963, 'Motion Graphic Designer', 0.3333333333333333]],
#  '327fae2f-0a4c-48e0-aeee-356cd9e5bad6': [[48682,
#    'QA Engineer',
#    0.5833333333333333]],
#  'd464d48d-db21-45ed-9571-1660cbbba08a': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [13844, 'Business Development Manager', 0.5833333333333333],
#   [82785, 'HR Officer', 0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [90991, 'Service/Business Designer', 0.41666666666666663],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [97963, 'Business Development Manager', 0.16666666666666666],
#   [75262, 'Technical Project Manager', 0.16666666666666666]],
#  '72aba292-6731-4b83-8ee1-17ada76678eb': [[60137,
#    'Data Architect',
#    0.5833333333333333]],
#  'f3264656-dff7-4e70-92af-c9bd14f9e078': [[60137,
#    'Data Architect',
#    0.5833333333333333]],
#  'a9883afd-7b48-4be3-9b7a-ffaf690e1b11': [[97963,
#    'Community Manager',
#    0.5833333333333333],
#   [85932, 'Software Architect', 0.5833333333333333],
#   [75262, 'Motion Graphic Designer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [90991, 'Scrum Master', 0.41666666666666663],
#   [71893, 'Online Marketing Expert', 0.3611111111111111],
#   [90991, 'Risk & Compliance Consultant', 0.16666666666666666],
#   [29145, 'Brand Designer', 0.16666666666666666]],
#  '943c01ec-0409-46a3-af83-5dec51d73216': [[97963,
#    'Community Manager',
#    0.5833333333333333],
#   [85932, 'Software Architect', 0.5833333333333333],
#   [75262, 'Motion Graphic Designer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [90991, 'Scrum Master', 0.41666666666666663],
#   [71893, 'Online Marketing Expert', 0.3611111111111111],
#   [90991, 'Risk & Compliance Consultant', 0.16666666666666666],
#   [29145, 'Brand Designer', 0.16666666666666666]],
#  '54a2c68c-4795-4d74-81a6-b584b042825d': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [48682, 'Management Consultant', 0.5833333333333333],
#   [48682, 'QA Engineer', 0.5833333333333333],
#   [13844, 'Business Development Manager', 0.5833333333333333],
#   [71893, 'Brand Expert', 0.5833333333333333],
#   [60137, 'Technical Project Manager', 0.5833333333333333],
#   [60137, 'Crypto / Web 3.0 Engineer', 0.5833333333333333],
#   [60137, 'Scrum Master', 0.5833333333333333],
#   [60137, 'Data Architect', 0.5833333333333333],
#   [75262, 'Data Engineer', 0.5833333333333333],
#   [75262, 'Motion Graphic Designer', 0.5833333333333333],
#   [82785, 'HR Officer', 0.5833333333333333],
#   [29145, 'Brand Designer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [13844, 'Cloud Expert', 0.41666666666666663],
#   [90991, 'Service/Business Designer', 0.41666666666666663]],
#  '1dd50c28-f6bb-43db-9a59-d0bc922a5c6b': [[97963,
#    'People & Culture Manager',
#    0.16666666666666666]],
#  '59464492-5c1f-416b-96c0-1c6d794acbc4': [[13844,
#    'Product Owner',
#    0.41666666666666663],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333]],
#  'a65fcf6b-6b64-4459-b971-99a122a220fe': [[60137,
#    'Data Architect',
#    0.5833333333333333],
#   [97963, 'Business Development Manager', 0.16666666666666666]],
#  '451e09fc-0227-4289-b907-b1cad7941c2d': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [48682, 'Management Consultant', 0.5833333333333333],
#   [13844, 'Business Development Manager', 0.5833333333333333],
#   [90991, 'Service/Business Designer', 0.5277777777777778],
#   [75262, 'Technical Project Manager', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.2777777777777778]],
#  '391141b4-5860-4cb1-a8db-b053e3e41d50': [[29145,
#    'Product Designer',
#    0.5833333333333333],
#   [48682, 'CX / Business Designer', 0.5277777777777778],
#   [90991, 'Service/Business Designer', 0.41666666666666663],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [97963, 'Business Development Manager', 0.16666666666666666]],
#  '956b726a-72ff-4198-af96-e7e14c01762c': [[85932,
#    'Service/Business Designer',
#    0.5833333333333333],
#   [97963, 'Business Development Manager', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.16666666666666666]],
#  '225058c0-32b8-497e-803b-9867fc2e71ce': [[85932,
#    'Service/Business Designer',
#    0.5833333333333333],
#   [97963, 'Business Development Manager', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.16666666666666666]],
#  'c92b4986-37f4-44fe-b732-42542c84d57e': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [90991, 'Service/Business Designer', 0.41666666666666663]],
#  '4fc4b79e-9bae-4dea-b4f6-97f9ab7b6d57': [[75262,
#    'Motion Graphic Designer',
#    0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [90991, 'Risk & Compliance Consultant', 0.16666666666666666],
#   [29145, 'Brand Designer', 0.16666666666666666],
#   [75262, 'Technical Project Manager', 0.08333333333333333]],
#  'baeaf60b-7f85-4251-b301-5e8112788cff': [[60137,
#    'Technical Project Manager',
#    0.1111111111111111]],
#  '2c3582f9-e869-493c-b0f7-6341717f891f': [[60137,
#    'Technical Project Manager',
#    0.1111111111111111]],
#  '9d332bc4-ed7c-4110-bd7d-77b943f9aa8a': [[48682,
#    'QA Engineer',
#    0.3333333333333333],
#   [97963, 'Community Manager', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.2777777777777778],
#   [13844, 'Product Owner', 0.16666666666666666],
#   [90991, 'Risk & Compliance Consultant', 0.16666666666666666],
#   [82785, 'HR Officer', 0.16666666666666666],
#   [29145, 'Brand Designer', 0.16666666666666666],
#   [71893, 'Content Editor', 0.1111111111111111],
#   [75262, 'Technical Project Manager', 0.08333333333333333]],
#  'd42b8cc4-7f30-4138-81df-4d382c93869e': [[29145,
#    'Algorithms Engineer',
#    0.5833333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333]],
#  'fc74fa52-9d2a-4781-bd54-0fb0eaa5b449': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [82785, 'Security Engineer', 0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [48682, 'Management Consultant', 0.41666666666666663]],
#  '911f556d-a30e-4582-9e16-51f3b9a79742': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [82785, 'Security Engineer', 0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [48682, 'Management Consultant', 0.41666666666666663]],
#  '911776c7-39c0-4b31-871b-a0d8144462bd': [[29145,
#    'Algorithms Engineer',
#    0.5277777777777778],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Brand Expert', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [29145, 'Brand Designer', 0.2777777777777778],
#   [90991, 'Service/Business Designer', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.1111111111111111]],
#  '5c720401-ef8e-4ad3-8cab-4b538ee3bc84': [[29145,
#    'Algorithms Engineer',
#    0.5277777777777778],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Brand Expert', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [29145, 'Brand Designer', 0.2777777777777778],
#   [90991, 'Service/Business Designer', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.1111111111111111]],
#  '99543c8f-1c14-487f-ace8-cb3b7a6703a8': [[97963,
#    'Business Development Manager',
#    0.16666666666666666]],
#  '2e13c9ae-3de9-400a-b43f-f4ae4c120d56': [[85932,
#    'Software Architect',
#    0.5833333333333333],
#   [60137, 'Data Architect', 0.5833333333333333],
#   [85932, 'User Acquisition Manager', 0.41666666666666663],
#   [97963, 'Community Manager', 0.3333333333333333],
#   [97963, 'Motion Graphic Designer', 0.3333333333333333],
#   [85932, 'Management Consultant', 0.3333333333333333],
#   [60137, 'Technical Project Manager', 0.16666666666666666],
#   [60137, 'Scrum Master', 0.16666666666666666]],
#  'e1dce201-1ced-4291-89e9-5a3abc506db3': [[13844,
#    'Product Owner',
#    0.41666666666666663],
#   [90991, 'Risk & Compliance Consultant', 0.16666666666666666]],
#  '682ebe93-e9ac-4357-ae9d-8f2420068191': [[13844,
#    'Product Owner',
#    0.41666666666666663],
#   [90991, 'Risk & Compliance Consultant', 0.16666666666666666]],
#  'b94eb9b4-4ec9-4bdb-a269-2b2827a1d27f': [[97963,
#    'Business Development Manager',
#    0.5833333333333333],
#   [85932, 'Service/Business Designer', 0.5833333333333333],
#   [60137, 'Technical Project Manager', 0.3333333333333333]],
#  '392e6753-62c0-42ab-b9d9-533a1a23b965': [[97963,
#    'Business Development Manager',
#    0.5833333333333333],
#   [85932, 'Service/Business Designer', 0.5833333333333333],
#   [60137, 'Technical Project Manager', 0.3333333333333333]],
#  '65bc5b7c-fe86-432a-a87f-1997c3928025': [[60137,
#    'Crypto / Web 3.0 Engineer',
#    0.5833333333333333],
#   [75262, 'Strategy Consultant', 0.5833333333333333],
#   [90991, 'Chief of Staff', 0.5833333333333333],
#   [82785, 'CX / Business Designer', 0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [82785, 'Project Manager', 0.41666666666666663],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Brand Expert', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [71893, 'Networking/Infrastructure Engineer', 0.2777777777777778],
#   [29145, 'Brand Designer', 0.2777777777777778],
#   [13844, 'Cloud Architect', 0.16666666666666666]],
#  '90efc812-6fb4-45a2-8ae5-07ad00f9459a': [[97963,
#    'Motion Graphic Designer',
#    0.3611111111111111]],
#  '1e81e6ed-18fd-4a94-be91-14b01c033649': [[82785,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5277777777777778],
#   [85932, 'Service/Business Designer', 0.5],
#   [71893, 'Online Marketing Expert', 0.41666666666666663],
#   [82785, 'Project Manager', 0.41666666666666663],
#   [13844, 'Cloud Architect', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.1111111111111111]],
#  'd294371b-8167-4311-b7f6-b96b25ae806b': [[60137,
#    'Data Architect',
#    0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [29145, 'Game Designer', 0.41666666666666663],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [71893, 'Networking/Infrastructure Engineer', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [75262, 'Strategy Consultant', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [13844, 'Cloud Expert', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.16666666666666666],
#   [75262, 'Technical Project Manager', 0.16666666666666666]],
#  '2a408e8a-f15f-4343-a517-065c97fe22ab': [[60137,
#    'Data Architect',
#    0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [29145, 'Game Designer', 0.41666666666666663],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [71893, 'Networking/Infrastructure Engineer', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [75262, 'Strategy Consultant', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [13844, 'Cloud Expert', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.16666666666666666],
#   [75262, 'Technical Project Manager', 0.16666666666666666]],
#  '8b1b30f8-68be-40c8-9540-48585c4712e4': [[60137,
#    'Data Architect',
#    0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [29145, 'Game Designer', 0.41666666666666663],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [71893, 'Networking/Infrastructure Engineer', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [75262, 'Strategy Consultant', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [13844, 'Cloud Expert', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.16666666666666666],
#   [75262, 'Technical Project Manager', 0.16666666666666666]],
#  '1311e2ad-076b-4f26-b764-91b3b7f9b57c': [[60137,
#    'Data Architect',
#    0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [29145, 'Game Designer', 0.41666666666666663],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [71893, 'Networking/Infrastructure Engineer', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [75262, 'Strategy Consultant', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [13844, 'Cloud Expert', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.16666666666666666],
#   [75262, 'Technical Project Manager', 0.16666666666666666]],
#  '8a363f7d-30d8-466d-b294-fcafe30458e0': [[60137,
#    'Data Architect',
#    0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [29145, 'Game Designer', 0.41666666666666663],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [71893, 'Networking/Infrastructure Engineer', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [75262, 'Strategy Consultant', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [13844, 'Cloud Expert', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.16666666666666666],
#   [75262, 'Technical Project Manager', 0.16666666666666666]],
#  'df51abec-df24-443b-8ba4-cc688540d803': [[60137,
#    'Data Architect',
#    0.5277777777777778]],
#  'f48c1554-a03e-478f-bc76-a72b327643c7': [[60137,
#    'Crypto / Web 3.0 Engineer',
#    0.5833333333333333],
#   [60137, 'Data Architect', 0.5833333333333333],
#   [60137, 'Technical Project Manager', 0.16666666666666666]],
#  'cc9b516f-6eaa-4fe4-8e35-1e097b6f2fec': [[60137,
#    'Crypto / Web 3.0 Engineer',
#    0.5833333333333333],
#   [60137, 'Data Architect', 0.5833333333333333],
#   [60137, 'Technical Project Manager', 0.16666666666666666]],
#  '7c289152-9d76-4d0e-8937-73607bd64095': [[48682,
#    'Management Consultant',
#    0.41666666666666663]],
#  '0204e38c-a127-4c34-be2d-c58abebb2fe6': [[60137,
#    'Data Architect',
#    0.5833333333333333],
#   [60137, 'Technical Project Manager', 0.3333333333333333]],
#  '1ccf6057-94a1-4d98-a076-e488c568e217': [[48682,
#    'QA Engineer',
#    0.5833333333333333],
#   [82785, 'Security Engineer', 0.5277777777777778],
#   [48682, 'Management Consultant', 0.41666666666666663]],
#  '577281d2-b3ec-40f2-af1e-72278f4a6b26': [[29145,
#    'Product Designer',
#    0.5277777777777778]],
#  'fd8af902-9ae2-4346-ad5a-8db4e86e9597': [[13844,
#    'Product Owner',
#    0.5833333333333333],
#   [75262, 'Data Engineer', 0.5833333333333333],
#   [90991, 'Chief of Staff', 0.5277777777777778],
#   [71893, 'Networking/Infrastructure Engineer', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333]],
#  'bfe467b4-30d2-46ed-8ce6-373982a100fa': [[48682,
#    'CX / Business Designer',
#    0.3333333333333333],
#   [48682, 'Management Consultant', 0.3333333333333333],
#   [48682, 'QA Engineer', 0.3333333333333333],
#   [75262, 'Data Engineer', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [90991, 'Service/Business Designer', 0.16666666666666666]],
#  '04acebbf-abfb-4c6e-9327-4bd6e54d4b8a': [[60137,
#    'Data Architect',
#    0.41666666666666663],
#   [60137, 'Technical Project Manager', 0.16666666666666666]],
#  '4e4fbef5-50cf-4a32-9daa-4c470e5e2b68': [[85932,
#    'Service/Business Designer',
#    0.5833333333333333]],
#  '2ef44671-24f9-41c0-bec7-1d5d10cb76a3': [[75262,
#    'Data Engineer',
#    0.5277777777777778],
#   [29145, 'Algorithms Engineer', 0.5277777777777778]],
#  '1c40691a-657a-4cee-9f97-68026c59cb9b': [[29145,
#    'Algorithms Engineer',
#    0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [60137, 'Data Architect', 0.41666666666666663],
#   [29145, 'Game Designer', 0.41666666666666663],
#   [71893, 'Networking/Infrastructure Engineer', 0.3333333333333333],
#   [75262, 'Motion Graphic Designer', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [29145, 'Product Designer', 0.3333333333333333],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [48682, 'CX / Business Designer', 0.16666666666666666],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [13844, 'Cloud Expert', 0.16666666666666666],
#   [71893, 'Online Marketing Expert', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.16666666666666666],
#   [60137, 'Scrum Master', 0.16666666666666666],
#   [75262, 'Strategy Consultant', 0.16666666666666666],
#   [75262, 'Technical Project Manager', 0.16666666666666666],
#   [90991, 'Scrum Master', 0.16666666666666666],
#   [82785, 'Security Engineer', 0.16666666666666666],
#   [29145, 'Brand Designer', 0.16666666666666666]],
#  '147c1ab9-5c58-41aa-9a7e-2a961a32c8dc': [[48682,
#    'Management Consultant',
#    0.5833333333333333]],
#  '79569ff1-0246-42ee-98f1-6ba0cac1930b': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [82785, 'Security Engineer', 0.5277777777777778],
#   [29145, 'Algorithms Engineer', 0.5277777777777778],
#   [75262, 'Technical Project Manager', 0.41666666666666663],
#   [13844, 'Product Owner', 0.3611111111111111]],
#  '221809a6-0674-41ae-a4de-9473c6abeff7': [[48682,
#    'QA Engineer',
#    0.5833333333333333],
#   [60137, 'Data Architect', 0.5833333333333333],
#   [75262, 'Data Engineer', 0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [82785, 'Project Manager', 0.41666666666666663],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [13844, 'Cloud Architect', 0.16666666666666666]],
#  '06c98639-5390-4125-83bc-c855f12a8b4b': [[71893,
#    'Content Editor',
#    0.5833333333333333],
#   [85932, 'Service/Business Designer', 0.5833333333333333],
#   [75262, 'Data Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [97963, 'Community Manager', 0.5277777777777778],
#   [97963, 'Motion Graphic Designer', 0.5277777777777778],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [97963, 'Business Development Manager', 0.41666666666666663],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [82785, 'Project Manager', 0.3611111111111111]],
#  '52a05fbf-5758-44d2-9caa-2839b9624145': [[75262,
#    'Data Engineer',
#    0.5833333333333333],
#   [90991, 'Chief of Staff', 0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [75262, 'Strategy Consultant', 0.41666666666666663],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [13844, 'Cloud Expert', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.16666666666666666]],
#  '5a2efc59-cb37-45f5-899e-b5facdbbf744': [[29145,
#    'Algorithms Engineer',
#    0.6388888888888888],
#   [90991, 'Risk & Compliance Consultant', 0.38888888888888884],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [97963, 'Business Development Manager', 0.16666666666666666]],
#  'e897ec44-460b-4894-89da-4306c9398465': [[29145,
#    'Algorithms Engineer',
#    0.6388888888888888],
#   [90991, 'Risk & Compliance Consultant', 0.38888888888888884],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [97963, 'Business Development Manager', 0.16666666666666666]],
#  '552acf73-d2ad-4403-a976-38c8e8c426fa': [[60137,
#    'Data Architect',
#    0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [48682, 'Management Consultant', 0.3333333333333333],
#   [97963, 'Business Development Manager', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [60137, 'Technical Project Manager', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [29145, 'Product Designer', 0.3333333333333333],
#   [90991, 'Service/Business Designer', 0.16666666666666666]],
#  '0357660f-3fab-4f92-869d-769fb1d2baf2': [[97963,
#    'Community Manager',
#    0.5833333333333333],
#   [85932, 'Software Architect', 0.5833333333333333],
#   [60137, 'Scrum Master', 0.5833333333333333]],
#  '77cc378e-8c8f-4a57-b5dd-a84a16165a9b': [[29145,
#    'Product Designer',
#    0.5833333333333333],
#   [90991, 'Service/Business Designer', 0.41666666666666663],
#   [82785, 'HR Officer', 0.41666666666666663],
#   [48682, 'CX / Business Designer', 0.3611111111111111],
#   [82785, 'Project Manager', 0.3611111111111111],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333]],
#  'b2138ae2-9899-4bdb-9f06-7090848bc0ee': [[48682,
#    'QA Engineer',
#    0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [71893, 'Online Marketing Expert', 0.5277777777777778]],
#  'ca09892b-ee39-4b06-bf4c-d9fa2fb47828': [[85932,
#    'Service/Business Designer',
#    0.5],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [90991, 'Chief of Staff', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [71893, 'Networking/Infrastructure Engineer', 0.2777777777777778],
#   [75262, 'Strategy Consultant', 0.16666666666666666]],
#  '8e2824fb-9105-4cdf-8947-07ef0554c339': [[85932,
#    'Service/Business Designer',
#    0.5],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [90991, 'Chief of Staff', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [71893, 'Networking/Infrastructure Engineer', 0.2777777777777778],
#   [75262, 'Strategy Consultant', 0.16666666666666666]],
#  'c5b9ee0c-b96e-451d-8fa5-1cb440296289': [[13844,
#    'Business Development Manager',
#    0.5833333333333333],
#   [90991, 'Chief of Staff', 0.5833333333333333],
#   [48682, 'CX / Business Designer', 0.41666666666666663],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [82785, 'Security Engineer', 0.41666666666666663],
#   [29145, 'Game Designer', 0.41666666666666663]],
#  '058a5c71-eab9-484a-bd22-663043a7947d': [[13844,
#    'Business Development Manager',
#    0.5833333333333333],
#   [90991, 'Chief of Staff', 0.5833333333333333],
#   [48682, 'CX / Business Designer', 0.41666666666666663],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [82785, 'Security Engineer', 0.41666666666666663],
#   [29145, 'Game Designer', 0.41666666666666663]],
#  '52c7b612-9b03-48c0-b9a7-5cbae38eeced': [[48682,
#    'CX / Business Designer',
#    0.3333333333333333],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.2777777777777778],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [75262, 'Technical Project Manager', 0.16666666666666666],
#   [90991, 'Service/Business Designer', 0.1111111111111111]],
#  'd2c206cb-3b51-4bb7-829e-b6732a707593': [[48682,
#    'CX / Business Designer',
#    0.3333333333333333],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.2777777777777778],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [75262, 'Technical Project Manager', 0.16666666666666666],
#   [90991, 'Service/Business Designer', 0.1111111111111111]],
#  'e4f7e2bf-4f48-4de5-9ec3-9da012a95004': [[48682,
#    'CX / Business Designer',
#    0.3333333333333333],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.2777777777777778],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [75262, 'Technical Project Manager', 0.16666666666666666],
#   [90991, 'Service/Business Designer', 0.1111111111111111]],
#  '4340904c-d56d-428d-b739-a0743afccd2c': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [60137, 'Crypto / Web 3.0 Engineer', 0.5833333333333333],
#   [60137, 'Scrum Master', 0.5833333333333333],
#   [90991, 'Service/Business Designer', 0.5833333333333333],
#   [82785, 'HR Officer', 0.5833333333333333],
#   [75262, 'Data Engineer', 0.5277777777777778],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Brand Expert', 0.3333333333333333],
#   [60137, 'Technical Project Manager', 0.2777777777777778],
#   [29145, 'Brand Designer', 0.2777777777777778],
#   [13844, 'Cloud Expert', 0.1111111111111111]],
#  '00a5b87f-2c34-47d7-b790-526792a1b012': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [60137, 'Crypto / Web 3.0 Engineer', 0.5833333333333333],
#   [60137, 'Scrum Master', 0.5833333333333333],
#   [90991, 'Service/Business Designer', 0.5833333333333333],
#   [82785, 'HR Officer', 0.5833333333333333],
#   [75262, 'Data Engineer', 0.5277777777777778],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Brand Expert', 0.3333333333333333],
#   [60137, 'Technical Project Manager', 0.2777777777777778],
#   [29145, 'Brand Designer', 0.2777777777777778],
#   [13844, 'Cloud Expert', 0.1111111111111111]],
#  '4bcdcc78-8870-4c7d-867e-b2eeda60a8c6': [[85932,
#    'User Acquisition Manager',
#    0.3611111111111111]],
#  'f55ee2d8-36f2-457a-b9d9-88f7981c1749': [[13844,
#    'Product Owner',
#    0.5833333333333333],
#   [71893, 'Networking/Infrastructure Engineer', 0.38888888888888884],
#   [75262, 'Data Engineer', 0.38888888888888884],
#   [90991, 'Risk & Compliance Consultant', 0.38888888888888884],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333],
#   [48682, 'CX / Business Designer', 0.2777777777777778],
#   [90991, 'Chief of Staff', 0.2777777777777778],
#   [48682, 'Management Consultant', 0.2222222222222222],
#   [13844, 'Cloud Expert', 0.2222222222222222],
#   [90991, 'Service/Business Designer', 0.16666666666666666]],
#  'f8c31f2e-cec0-4c93-9d16-b57c1700c278': [[97963,
#    'Business Development Manager',
#    0.5833333333333333],
#   [71893, 'Online Marketing Expert', 0.5833333333333333],
#   [85932, 'Service/Business Designer', 0.5833333333333333],
#   [60137, 'Crypto / Web 3.0 Engineer', 0.5833333333333333],
#   [75262, 'Strategy Consultant', 0.5833333333333333],
#   [90991, 'Chief of Staff', 0.5833333333333333],
#   [97963, 'Community Manager', 0.5277777777777778],
#   [13844, 'Cloud Architect', 0.5277777777777778],
#   [85932, 'Software Architect', 0.5277777777777778],
#   [82785, 'Project Manager', 0.41666666666666663],
#   [29145, 'Game Designer', 0.41666666666666663],
#   [97963, 'People & Culture Manager', 0.3611111111111111],
#   [85932, 'User Acquisition Manager', 0.3611111111111111]],
#  '00a85268-8812-4ec5-adba-491f4ef9f2f8': [[97963,
#    'Business Development Manager',
#    0.5833333333333333],
#   [71893, 'Online Marketing Expert', 0.5833333333333333],
#   [85932, 'Service/Business Designer', 0.5833333333333333],
#   [60137, 'Crypto / Web 3.0 Engineer', 0.5833333333333333],
#   [75262, 'Strategy Consultant', 0.5833333333333333],
#   [90991, 'Chief of Staff', 0.5833333333333333],
#   [97963, 'Community Manager', 0.5277777777777778],
#   [13844, 'Cloud Architect', 0.5277777777777778],
#   [85932, 'Software Architect', 0.5277777777777778],
#   [82785, 'Project Manager', 0.41666666666666663],
#   [29145, 'Game Designer', 0.41666666666666663],
#   [97963, 'People & Culture Manager', 0.3611111111111111],
#   [85932, 'User Acquisition Manager', 0.3611111111111111]],
#  '9f84f33c-b607-44ff-8961-646375ff5e55': [[48682,
#    'Management Consultant',
#    0.41666666666666663]],
#  '3ad02a80-9085-4e22-b9f7-e53ec13d109a': [[75262,
#    'Data Engineer',
#    0.3333333333333333],
#   [90991, 'Chief of Staff', 0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333],
#   [48682, 'Management Consultant', 0.16666666666666666]],
#  'b2ca1d7b-1326-488d-a76b-ead019c1aff4': [[75262,
#    'Data Engineer',
#    0.3333333333333333],
#   [90991, 'Chief of Staff', 0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333],
#   [48682, 'Management Consultant', 0.16666666666666666]],
#  'efcd81b4-d760-4030-b036-bc19be4fe671': [[75262,
#    'Data Engineer',
#    0.3333333333333333],
#   [90991, 'Chief of Staff', 0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333],
#   [48682, 'Management Consultant', 0.16666666666666666]],
#  'b73cc2cd-57db-41ab-b32e-9e8a8e7bb706': [[29145,
#    'Product Designer',
#    0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [48682, 'QA Engineer', 0.3333333333333333],
#   [71893, 'Content Editor', 0.1111111111111111]],
#  '39e83762-fc8e-4e5d-8502-e1508bb77c72': [[29145,
#    'Product Designer',
#    0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [48682, 'QA Engineer', 0.3333333333333333],
#   [71893, 'Content Editor', 0.1111111111111111]],
#  '2fe1d935-099f-4608-8b18-69e542d7c7a5': [[48682,
#    'QA Engineer',
#    0.5833333333333333],
#   [60137, 'Technical Project Manager', 0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [13844, 'Cloud Architect', 0.41666666666666663],
#   [29145, 'Game Designer', 0.41666666666666663]],
#  'fbc4ba4e-1b52-4d9d-947e-a230ff7e7c87': [[48682,
#    'QA Engineer',
#    0.5833333333333333],
#   [60137, 'Technical Project Manager', 0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [13844, 'Cloud Architect', 0.41666666666666663],
#   [29145, 'Game Designer', 0.41666666666666663]],
#  'b51f90a3-195a-4cb4-b861-25d4f690c2d2': [[48682,
#    'QA Engineer',
#    0.5833333333333333],
#   [60137, 'Technical Project Manager', 0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5833333333333333],
#   [13844, 'Cloud Architect', 0.41666666666666663],
#   [29145, 'Game Designer', 0.41666666666666663]],
#  'e427a46f-b373-4c7d-ba0a-e6a4278b7cf9': [[48682,
#    'Management Consultant',
#    0.5833333333333333],
#   [97963, 'Community Manager', 0.5833333333333333],
#   [75262, 'Motion Graphic Designer', 0.5833333333333333],
#   [82785, 'HR Officer', 0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [29145, 'Brand Designer', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.2777777777777778],
#   [71893, 'Online Marketing Expert', 0.2777777777777778]],
#  '804031d8-0e43-43b4-bd5c-3b18d333349b': [[13844,
#    'Product Owner',
#    0.41666666666666663],
#   [48682, 'QA Engineer', 0.3333333333333333],
#   [97963, 'Community Manager', 0.3333333333333333],
# ...
#    'Game Designer',
#    0.41666666666666663],
#   [29145, 'Product Designer', 0.3333333333333333]],
#  'f4c42f6e-a0a0-4da4-8037-d5e96dae08b1': [[29145,
#    'Game Designer',
#    0.41666666666666663],
#   [29145, 'Product Designer', 0.3333333333333333]],
#  'c53be1be-4a03-4ac3-baf6-b876dfe30264': [[13844,
#    'Product Owner',
#    0.41666666666666663],
#   [75262, 'Motion Graphic Designer', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [29145, 'Brand Designer', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.2777777777777778],
#   [71893, 'Brand Expert', 0.2777777777777778],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [82785, 'Project Manager', 0.1111111111111111]],
#  '9df8cb6c-8de4-49e2-bdc7-5a42a04a6c45': [[13844,
#    'Product Owner',
#    0.41666666666666663],
#   [75262, 'Motion Graphic Designer', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [29145, 'Brand Designer', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.2777777777777778],
#   [71893, 'Brand Expert', 0.2777777777777778],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [82785, 'Project Manager', 0.1111111111111111]],
#  'e026b3b7-db09-4233-970b-d496149fe546': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [90991, 'Chief of Staff', 0.5833333333333333],
#   [82785, 'Security Engineer', 0.5833333333333333],
#   [48682, 'Management Consultant', 0.41666666666666663]],
#  'a0d1c2b8-3ee8-433c-a9b0-f7caca55555e': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [90991, 'Chief of Staff', 0.5833333333333333],
#   [82785, 'Security Engineer', 0.5833333333333333],
#   [48682, 'Management Consultant', 0.41666666666666663]],
#  'b17016f7-953e-4fc9-9517-524ec157d9dc': [[29145,
#    'Algorithms Engineer',
#    0.5833333333333333],
#   [29145, 'Product Designer', 0.5277777777777778],
#   [29145, 'Game Designer', 0.41666666666666663],
#   [13844, 'Cloud Architect', 0.1111111111111111]],
#  '0c904715-3bbe-4050-bc23-083d4ca0f2d6': [[48682,
#    'QA Engineer',
#    0.3333333333333333],
#   [90991, 'Scrum Master', 0.3333333333333333],
#   [29145, 'Product Designer', 0.3333333333333333],
#   [71893, 'Online Marketing Expert', 0.2777777777777778],
#   [82785, 'Project Manager', 0.1111111111111111]],
#  '86877d86-de24-4759-b031-3e1ef72e123a': [[13844,
#    'Product Owner',
#    0.41666666666666663],
#   [48682, 'QA Engineer', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.2777777777777778],
#   [71893, 'Brand Expert', 0.2777777777777778],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [60137, 'Scrum Master', 0.16666666666666666],
#   [82785, 'Project Manager', 0.1111111111111111]],
#  'f63533c6-c3c3-4e92-8284-eb05cab56255': [[75262,
#    'Data Engineer',
#    0.5833333333333333],
#   [97963, 'Business Development Manager', 0.3333333333333333]],
#  '8e08263c-c1f9-413f-8ede-67786f0b61cd': [[29145,
#    'Algorithms Engineer',
#    0.5833333333333333],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [29145, 'Product Designer', 0.3333333333333333],
#   [48682, 'CX / Business Designer', 0.16666666666666666],
#   [48682, 'Management Consultant', 0.16666666666666666],
#   [97963, 'Business Development Manager', 0.16666666666666666],
#   [71893, 'Online Marketing Expert', 0.16666666666666666],
#   [75262, 'Technical Project Manager', 0.16666666666666666],
#   [90991, 'Service/Business Designer', 0.16666666666666666],
#   [82785, 'HR Officer', 0.16666666666666666],
#   [29145, 'Brand Designer', 0.16666666666666666]],
#  '2d8701ec-a6a5-4089-9ade-eb99a094fe34': [[29145,
#    'Algorithms Engineer',
#    0.5833333333333333]],
#  '096e3841-ec64-42fd-a52e-3358f1a8e834': [[29145,
#    'Algorithms Engineer',
#    0.5833333333333333]],
#  '3704e317-6fcd-4061-89f5-ecfa30d600d6': [[29145,
#    'Algorithms Engineer',
#    0.5833333333333333]],
#  'f1527b96-cf64-4e26-8ba9-17af5b1b4cba': [[60137,
#    'Technical Project Manager',
#    0.1111111111111111]],
#  '0cbb9b36-38cc-4b8f-b557-475b605e468d': [[60137,
#    'Technical Project Manager',
#    0.1111111111111111]],
#  '99b232ee-5dfb-496f-846f-8394ff83962a': [[60137,
#    'Technical Project Manager',
#    0.1111111111111111]],
#  '34abbdcf-f84a-4667-8902-fb17d1ade546': [[60137,
#    'Technical Project Manager',
#    0.1111111111111111]],
#  '12f13c28-82f7-437b-b1a8-ba0ffa451dab': [[60137,
#    'Technical Project Manager',
#    0.1111111111111111]],
#  'bbc5e360-2448-4d25-997f-62616761de3d': [[85932,
#    'Service/Business Designer',
#    0.3333333333333333],
#   [29145, 'Product Designer', 0.3333333333333333],
#   [97963, 'Business Development Manager', 0.16666666666666666],
#   [82785, 'Project Manager', 0.1111111111111111]],
#  '3a3298b4-150d-4923-97ef-0cfa19500f31': [[75262,
#    'Data Engineer',
#    0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333],
#   [29145, 'Product Designer', 0.5277777777777778],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [82785, 'Project Manager', 0.41666666666666663],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [13844, 'Cloud Architect', 0.1111111111111111]],
#  '29f4e5f3-746d-45fb-ab65-3ae758c1e0b5': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [13844, 'Business Development Manager', 0.5833333333333333],
#   [71893, 'Online Marketing Expert', 0.5833333333333333],
#   [82785, 'HR Officer', 0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5277777777777778],
#   [29145, 'Brand Designer', 0.5277777777777778],
#   [90991, 'Service/Business Designer', 0.41666666666666663]],
#  'fe9fa463-a97e-4f66-8711-503faa7ae510': [[90991,
#    'Chief of Staff',
#    0.5277777777777778],
#   [75262, 'Data Engineer', 0.41666666666666663],
#   [90991, 'Service/Business Designer', 0.41666666666666663],
#   [82785, 'Security Engineer', 0.41666666666666663],
#   [48682, 'CX / Business Designer', 0.3611111111111111]],
#  'db1d5960-8775-4080-9817-b305463f39c6': [[29145,
#    'Algorithms Engineer',
#    0.5277777777777778],
#   [48682, 'CX / Business Designer', 0.3333333333333333],
#   [13844, 'Business Development Manager', 0.3333333333333333],
#   [90991, 'Service/Business Designer', 0.16666666666666666]],
#  '8841f0af-d7e9-42d1-b1c8-3c01e8dd8573': [[60137,
#    'Crypto / Web 3.0 Engineer',
#    0.5833333333333333],
#   [60137, 'Data Architect', 0.41666666666666663],
#   [60137, 'Technical Project Manager', 0.16666666666666666]],
#  'd45b4eb9-d67b-4078-9130-a039f5bb1b1e': [[82785,
#    'HR Officer',
#    0.5833333333333333],
#   [48682, 'CX / Business Designer', 0.5277777777777778],
#   [97963, 'Business Development Manager', 0.41666666666666663],
#   [90991, 'Service/Business Designer', 0.41666666666666663],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333]],
#  '5cb8d356-ddb9-4dfb-adad-7cd13a96eb5a': [[75262,
#    'Motion Graphic Designer',
#    0.5833333333333333],
#   [48682, 'CX / Business Designer', 0.5277777777777778],
#   [90991, 'Chief of Staff', 0.5277777777777778],
#   [29145, 'Game Designer', 0.41666666666666663],
#   [82785, 'Project Manager', 0.3611111111111111],
#   [71893, 'Networking/Infrastructure Engineer', 0.3333333333333333]],
#  '905fe3c2-5351-4ed7-bc7a-a3fc25b29e21': [[97963,
#    'Motion Graphic Designer',
#    0.5833333333333333]],
#  '61253b65-e485-4ac4-9ba0-a936d96a4d16': [[97963,
#    'Motion Graphic Designer',
#    0.5833333333333333]],
#  '0d8f1f1a-5b9c-403f-af30-4c45eaf0a398': [[97963,
#    'Motion Graphic Designer',
#    0.5833333333333333]],
#  'fdd213bd-36be-4283-85f6-b997f7b1b7cb': [[97963,
#    'Motion Graphic Designer',
#    0.5833333333333333]],
#  'efca3c15-b21d-4b7e-ae56-99bea456733c': [[48682,
#    'QA Engineer',
#    0.5833333333333333],
#   [97963, 'Community Manager', 0.5833333333333333],
#   [85932, 'Software Architect', 0.5833333333333333],
#   [13844, 'Business Development Manager', 0.5277777777777778],
#   [71893, 'Brand Expert', 0.5277777777777778],
#   [71893, 'Online Marketing Expert', 0.5277777777777778],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [60137, 'Scrum Master', 0.41666666666666663],
#   [82785, 'Project Manager', 0.3611111111111111],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333]],
#  'b926623e-13bf-479b-9007-96b28c0ca4f8': [[29145,
#    'Product Designer',
#    0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [71893, 'Content Editor', 0.2777777777777778]],
#  '694bc8b6-7508-4dbe-a119-1fca12badf1e': [[29145,
#    'Product Designer',
#    0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [71893, 'Content Editor', 0.2777777777777778]],
#  '6bc155f1-6f1a-4b92-bd5f-e393dbe31989': [[29145,
#    'Product Designer',
#    0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [71893, 'Content Editor', 0.2777777777777778]],
#  '1330cf9d-32aa-409f-8e8b-39daf5a9d897': [[29145,
#    'Product Designer',
#    0.5833333333333333],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [71893, 'Content Editor', 0.2777777777777778]],
#  'dcd903d6-60a8-45f4-bede-0a66c5cbe540': [[97963,
#    'Community Manager',
#    0.2777777777777778]],
#  '4498e4fe-5d79-4fb2-b8f8-89e9ec2cd634': [[29145,
#    'Product Designer',
#    0.5277777777777778]],
#  'befa6c34-4dfe-4046-9c04-cb53932f468e': [[13844,
#    'Product Owner',
#    0.41666666666666663]],
#  '1d0e1729-8d37-4a3c-8d8e-1adc3b9d20a0': [[13844,
#    'Product Owner',
#    0.41666666666666663]],
#  '12ec41c8-2555-4635-8b9d-ecb4aa4bdd15': [[90991,
#    'Chief of Staff',
#    0.5833333333333333]],
#  '21879248-a039-4071-b27c-c12a4725a5ce': [[90991,
#    'Chief of Staff',
#    0.5833333333333333]],
#  'f2bb371a-18d5-4a45-9762-234cf3f9d7c5': [[97963,
#    'Community Manager',
#    0.5833333333333333],
#   [97963, 'People & Culture Manager', 0.41666666666666663],
#   [85932, 'Management Consultant', 0.3333333333333333]],
#  'a409004f-c3f0-4f28-8296-a79d2af5d9d1': [[97963,
#    'Community Manager',
#    0.5833333333333333],
#   [97963, 'People & Culture Manager', 0.41666666666666663],
#   [85932, 'Management Consultant', 0.3333333333333333]],
#  'a3573870-ec82-456a-92ec-9ba2cccf984c': [[97963,
#    'Community Manager',
#    0.5277777777777778],
#   [85932, 'Service/Business Designer', 0.5]],
#  '89179ac8-eb9c-47e7-a2fd-c2d3b69530c1': [[13844,
#    'Product Owner',
#    0.41666666666666663],
#   [71893, 'Content Editor', 0.3333333333333333],
#   [85932, 'Service/Business Designer', 0.3333333333333333],
#   [75262, 'Data Engineer', 0.3333333333333333],
#   [29145, 'Product Designer', 0.3333333333333333],
#   [97963, 'Motion Graphic Designer', 0.2777777777777778],
#   [97963, 'Business Development Manager', 0.16666666666666666]],
#  'e3cf56a6-c3e7-4635-8e62-6fa66c00cb47': [[90991,
#    'Chief of Staff',
#    0.5833333333333333],
#   [75262, 'Data Engineer', 0.5277777777777778]],
#  '0b43ad6d-5edc-4d0f-9eea-ccd60be67218': [[90991,
#    'Chief of Staff',
#    0.5833333333333333],
#   [75262, 'Data Engineer', 0.5277777777777778]],
#  'c9005458-e1e5-4572-aad3-fa6685947d63': [[90991,
#    'Chief of Staff',
#    0.5833333333333333],
#   [75262, 'Data Engineer', 0.5277777777777778]],
#  '748917c5-f937-419e-a593-8c726531cb4c': [[90991,
#    'Chief of Staff',
#    0.5833333333333333],
#   [75262, 'Data Engineer', 0.5277777777777778]],
#  'd72121d7-4dd6-41b7-9147-6a64a720bb66': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [13844, 'Product Owner', 0.5833333333333333],
#   [71893, 'Online Marketing Expert', 0.5833333333333333],
#   [90991, 'Chief of Staff', 0.5833333333333333],
#   [82785, 'HR Officer', 0.5833333333333333]],
#  '3a7ec862-886d-4fca-a3c7-66815e249bed': [[71893,
#    'Online Marketing Expert',
#    0.5833333333333333],
#   [75262, 'Data Engineer', 0.5833333333333333],
#   [90991, 'Chief of Staff', 0.5833333333333333],
#   [97963, 'Community Manager', 0.5277777777777778],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333]],
#  'd672e348-7d76-4cb9-bd8e-4ddb7b33d444': [[71893,
#    'Online Marketing Expert',
#    0.5833333333333333],
#   [75262, 'Data Engineer', 0.5833333333333333],
#   [90991, 'Chief of Staff', 0.5833333333333333],
#   [97963, 'Community Manager', 0.5277777777777778],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333]],
#  'e0fc3db5-947a-421c-b502-078595ce337d': [[48682,
#    'QA Engineer',
#    0.5833333333333333],
#   [29145, 'Algorithms Engineer', 0.5833333333333333]],
#  '81671133-8015-430a-83db-465ae9c2dd6e': [[48682,
#    'CX / Business Designer',
#    0.5833333333333333],
#   [13844, 'Business Development Manager', 0.5277777777777778],
#   [60137, 'Data Architect', 0.5277777777777778],
#   [29145, 'Algorithms Engineer', 0.5277777777777778],
#   [71893, 'Content Editor', 0.2777777777777778],
#   [60137, 'Technical Project Manager', 0.16666666666666666],
#   [75262, 'Technical Project Manager', 0.16666666666666666]],
#  '348a7ab1-3926-4058-9985-a14e93ecff25': [[29145,
#    'Algorithms Engineer',
#    0.5277777777777778],
#   [71893, 'Online Marketing Expert', 0.16666666666666666],
#   [60137, 'Technical Project Manager', 0.1111111111111111]],
#  'e7884168-4cd0-4a88-92cd-5ec7e0a4595a': [[48682,
#    'QA Engineer',
#    0.5833333333333333],
#   [97963, 'Community Manager', 0.5833333333333333],
#   [85932, 'Software Architect', 0.5833333333333333],
#   [13844, 'Business Development Manager', 0.5277777777777778],
#   [71893, 'Brand Expert', 0.5277777777777778],
#   [71893, 'Online Marketing Expert', 0.5277777777777778],
#   [48682, 'Management Consultant', 0.41666666666666663],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [82785, 'Project Manager', 0.3611111111111111],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333]],
#  'a48505b8-822c-4f1e-a1bf-db195011e6d3': [[85932,
#    'Service/Business Designer',
#    0.5],
#   [82785, 'Project Manager', 0.3611111111111111]],
#  '4d01b64f-bde0-46b2-9c89-096814e1a21e': [[60137,
#    'Technical Project Manager',
#    0.16666666666666666]],
#  '0dc7fe56-ed92-4c1c-a079-c458af810286': [[60137,
#    'Technical Project Manager',
#    0.16666666666666666]],
#  '785d0c79-27a9-479b-88e7-7868c1be48e0': [[60137,
#    'Technical Project Manager',
#    0.16666666666666666]],
#  '4007a498-d447-4b76-b99c-bd94792e9720': [[90991,
#    'Chief of Staff',
#    0.5277777777777778],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [75262, 'Data Engineer', 0.41666666666666663],
#   [82785, 'Security Engineer', 0.41666666666666663],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333]],
#  'ec3b2815-70ca-4b10-8c7a-9a7f1027765a': [[90991,
#    'Chief of Staff',
#    0.3333333333333333],
#   [82785, 'Security Engineer', 0.3333333333333333]],
#  '80dbb387-89d0-4629-87c9-86cf9bf80d3d': [[82785,
#    'HR Officer',
#    0.5833333333333333],
#   [48682, 'CX / Business Designer', 0.5277777777777778],
#   [75262, 'Data Engineer', 0.5277777777777778],
#   [90991, 'Chief of Staff', 0.5277777777777778],
#   [13844, 'Product Owner', 0.41666666666666663],
#   [90991, 'Service/Business Designer', 0.41666666666666663],
#   [13844, 'Cloud Expert', 0.3611111111111111],
#   [71893, 'Networking/Infrastructure Engineer', 0.2777777777777778]],
#  '5c9bf91d-a743-4f74-a30d-93f6f3ab1a5a': [[13844,
#    'Product Owner',
#    0.41666666666666663],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [97963, 'Community Manager', 0.2777777777777778],
#   [71893, 'Content Editor', 0.2777777777777778],
#   [48682, 'Management Consultant', 0.16666666666666666]],
#  'd63c30ee-4552-4d0d-9e33-57bd92fec5e6': [[13844,
#    'Product Owner',
#    0.41666666666666663],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [97963, 'Community Manager', 0.2777777777777778],
#   [71893, 'Content Editor', 0.2777777777777778],
#   [48682, 'Management Consultant', 0.16666666666666666]],
#  'caeaa8b2-cc94-4c7a-aa86-b542635089bc': [[13844,
#    'Product Owner',
#    0.41666666666666663],
#   [90991, 'Risk & Compliance Consultant', 0.3333333333333333],
#   [82785, 'HR Officer', 0.3333333333333333],
#   [97963, 'Community Manager', 0.2777777777777778],
#   [71893, 'Content Editor', 0.2777777777777778],
#   [48682, 'Management Consultant', 0.16666666666666666]]}
