# %%
# !pip install neo4j
# Out:
# Collecting neo4j
#   Downloading neo4j-5.12.0.tar.gz (190 kB)
#      |████████████████████████████████| 190 kB 5.5 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: pytz in ./opt/anaconda3/lib/python3.9/site-packages (from neo4j) (2021.3)
# Building wheels for collected packages: neo4j
#   Building wheel for neo4j (PEP 517) ... done
#   Created wheel for neo4j: filename=neo4j-5.12.0-py3-none-any.whl size=263745 sha256=1e69d8c39be93194c1e478178637344a683382de47b75f12055b0a81417c47dc
#   Stored in directory: /Users/jiangyiwei/Library/Caches/pip/wheels/57/f0/58/85b6179dfa6386d12499758bd654fc095bd01b6df38a99301d
# Successfully built neo4j
# Installing collected packages: neo4j
# Successfully installed neo4j-5.12.0

# %%
# !pip install spacy
# !python -m spacy download en_core_web_lg
# Out:
# Collecting spacy
#   Downloading spacy-3.6.1-cp39-cp39-macosx_10_9_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 7.0 MB/s eta 0:00:01
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy) (4.64.0)
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 5.3 MB/s eta 0:00:011
# Requirement already satisfied: jinja2 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.11.3)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.10.7)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.8-cp39-cp39-macosx_10_9_x86_64.whl (42 kB)
#      |████████████████████████████████| 42 kB 2.0 MB/s  eta 0:00:01
# Collecting pathy>=0.10.0
#   Downloading pathy-0.10.2-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 8.3 MB/s  eta 0:00:01
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.27.1)
# Collecting typer<0.10.0,>=0.3.0
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 6.3 MB/s eta 0:00:011
# Requirement already satisfied: packaging>=20.0 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy) (21.3)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 6.5 MB/s eta 0:00:01
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.10-cp39-cp39-macosx_10_9_x86_64.whl (26 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.7-cp39-cp39-macosx_10_9_x86_64.whl (492 kB)
#      |████████████████████████████████| 492 kB 5.9 MB/s eta 0:00:01
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.9-py3-none-any.whl (17 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp39-cp39-macosx_10_9_x86_64.whl (133 kB)
#      |████████████████████████████████| 133 kB 7.4 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in ./opt/anaconda3/lib/python3.9/site-packages (from spacy) (61.2.0)
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.12-cp39-cp39-macosx_10_9_x86_64.whl (875 kB)
#      |████████████████████████████████| 875 kB 7.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.15.0 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy) (3.0.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.9)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.10-cp39-cp39-macosx_10_9_x86_64.whl (6.1 MB)
#      |████████████████████████████████| 6.1 MB 8.9 MB/s eta 0:00:01
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.3-py3-none-any.whl (34 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./opt/anaconda3/lib/python3.9/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in ./opt/anaconda3/lib/python3.9/site-packages (from jinja2->spacy) (2.0.1)
# Installing collected packages: catalogue, srsly, murmurhash, cymem, wasabi, typer, smart-open, preshed, confection, blis, thinc, spacy-loggers, spacy-legacy, pathy, langcodes, spacy
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 5.1.0
#     Uninstalling smart-open-5.1.0:
#       Successfully uninstalled smart-open-5.1.0
# Successfully installed blis-0.7.10 catalogue-2.0.9 confection-0.1.3 cymem-2.0.8 langcodes-3.3.0 murmurhash-1.0.10 pathy-0.10.2 preshed-3.0.9 smart-open-6.4.0 spacy-3.6.1 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.7 thinc-8.1.12 typer-0.9.0 wasabi-1.1.2
# Collecting en-core-web-lg==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.6.0/en_core_web_lg-3.6.0-py3-none-any.whl (587.7 MB)
#      |████████████████████████████████| 587.7 MB 26 kB/s  eta 0:00:012   |███▊                            | 69.0 MB 6.4 MB/s eta 0:01:21     |███████████████████████▍        | 429.0 MB 6.5 MB/s eta 0:00:25
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in ./opt/anaconda3/lib/python3.9/site-packages (from en-core-web-lg==3.6.0) (3.6.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.0.8)
# Requirement already satisfied: setuptools in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (61.2.0)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.9.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (8.1.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.0.5)
# Requirement already satisfied: jinja2 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.1.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.0.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (4.64.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.0.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.4.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.0.9)
# Requirement already satisfied: numpy>=1.15.0 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.21.5)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (6.4.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.27.1)
# Requirement already satisfied: pathy>=0.10.0 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.10.2)
# Requirement already satisfied: packaging>=20.0 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (21.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./opt/anaconda3/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.10.7)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.0.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./opt/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.26.9)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./opt/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./opt/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./opt/anaconda3/lib/python3.9/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in ./opt/anaconda3/lib/python3.9/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.0.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
#Connect to Neo4j

# %%
from neo4j import GraphDatabase

class Neo4jConnection:
    def __init__(self, uri, user, pwd):
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        try:
            self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__user, self.__pwd))
        except Exception as e:
            print("Failed to create the driver:", e)

    def close(self):
        if self.__driver is not None:
            self.__driver.close()

    def query(self, query, parameters=None, db=None):
        assert self.__driver is not None, "Driver not initialized!"
        session = None
        response = None
        try:
            session = self.__driver.session(database=db) if db is not None else self.__driver.session()
            response = list(session.run(query, parameters))
        except Exception as e:
            print("Query failed:", e)
        finally:
            if session is not None:
                session.close()
        return response

conn = Neo4jConnection(uri="bolt://localhost:7687", user="neo4j", pwd="123456")

# %%
# Use Spacy to compare the similities between texts

# %%
import spacy

# Initialize spaCy model
nlp = spacy.load("en_core_web_lg")

def compute_similarity(text1, text2):
    # Check if the text exists and is not empty
    if not text1 or not text2:
        return 0.0

    doc1 = nlp(text1)
    doc2 = nlp(text2)
    return doc1.similarity(doc2)

# Read data by CQL
roles = conn.query("MATCH (r:Role) RETURN r.role_description, r.project_name, r.role_name")
applicants = conn.query("MATCH (a:Applicant) RETURN a.biography, a.UID")

# Compute textual similarity for each role and applicant
similarities = {}
for role in roles:
    role_desc = role["r.role_description"]
#     print(role_desc)
    for applicant in applicants:
        applicant_bio = applicant["a.biography"]
#         print(applicant_bio)

        # Check that description and resume are valid
        if role_desc and applicant_bio:
            key = (role["r.project_name"], role["r.role_name"], applicant["a.UID"])
            sim_score=compute_similarity(role_desc, applicant_bio)
            similarities[key] = sim_score

# %%
print(list(similarities.items())[:5])  # Print the first 5 similarity values
# Out:
# [(('Inc', 'Technical Product Manager', 'bb48d3b4-2724-4bd9-b050-430349ec7dc4'), 0.7248541582207213), (('Inc', 'Technical Product Manager', '08ade3a7-a2b8-4304-bfb3-c0c6285fc8d5'), 0.7224082255946336), (('Inc', 'Technical Product Manager', '93f9cf43-8c60-4b27-8535-bf8a121f61f6'), 0.7187216950136979), (('Inc', 'Technical Product Manager', '6f92a1ec-56c3-4ac6-9532-7e62116fa756'), 0.7194197972371968), (('Inc', 'Technical Product Manager', '135a7fd8-c368-4788-81ea-05db87b47e5a'), 0.720741503383385)]

# %%
# Store the results in Neo4j

for key, sim_score in similarities.items():
    project_name, role_name, applicant_uid = key
    cql = f"""
    MATCH (r:Role {{project_name: '{project_name}', role_name: '{role_name}'}}),
          (a:Applicant {{UID: '{applicant_uid}'}})
    MERGE (r)-[:HAS_TEXT_SIMILARITY {{score: {sim_score}}}]->(a)
    """
    conn.query(cql)

# %%
# role-talent matching

# %%
cql2 = """
MATCH (r:Role), (a:Applicant), (r)-[rel:HAS_TEXT_SIMILARITY]->(a)
WITH r, a,
    size([x IN r.required_skills WHERE x IN a.skills]) AS matchedRequiredSkills,
    size(r.required_skills) AS totalRequiredSkills,
    CASE WHEN r.Location = a.Location THEN 1 ELSE 0 END AS locationMatch,
    CASE WHEN r.Industry = a.industry THEN 1 ELSE 0 END AS industryMatch,
    CASE WHEN r.Language = a.language THEN 1 ELSE 0 END AS languageMatch,
    CASE WHEN r.availability_date <= a.availability THEN 1 ELSE 0 END AS availabilityMatch,
    CASE WHEN r.min_available_hours_per_week <= a.working_hours THEN 1 ELSE 0 END AS hoursMatch,
    rel.score * 0.25 AS textSimilarityScore

WHERE matchedRequiredSkills >= 0.75 * totalRequiredSkills

WITH r, a,
    1*matchedRequiredSkills + 1*locationMatch + 1*industryMatch + 1*languageMatch +
    1*availabilityMatch + 1*hoursMatch +
    size([x IN r.preferred_skills WHERE x IN a.skills]) * 0.5 +
    size([x IN r.tools WHERE x IN a.tools]) * 0.5 +
    CASE WHEN a.experience >= r.years_of_experience THEN 0.75 ELSE 0 END +
    textSimilarityScore AS totalScore

ORDER BY r.project_name, r.role_name, totalScore DESC

WITH r.project_name AS project_name, r.role_name AS role_name,
    COLLECT({applicant: a, score: totalScore})[0..5] AS topMatches
UNWIND topMatches AS match

RETURN project_name, role_name, match.applicant.first_name AS applicant_name, match.score AS score
ORDER BY project_name, role_name, score DESC;

"""

# %%
try:
    results = conn.query(cql2)
except Exception as e:
    print(f"Error executing CQL: {e}")


for record in results:
#     print(record)
    project_name = record.get('project_name', 'N/A')
    role_name = record.get('role_name', 'N/A')
    applicant_name = record.get('applicant_name', 'N/A')
    score = record.get('score', 'N/A')
    print(f"Project Name: {project_name}\nRole Name: {role_name}\nApplicant Name: {applicant_name}\nScore: {score}\n{'-'*50}")
# Out:
# Project Name: Group
# Role Name: Business Development Manager
# Applicant Name: Wendy
# Score: 6.932003013942328
# --------------------------------------------------
# Project Name: Group
# Role Name: Business Development Manager
# Applicant Name: Barry
# Score: 6.931802088021631
# --------------------------------------------------
# Project Name: Group
# Role Name: Business Development Manager
# Applicant Name: Lindsey
# Score: 6.930724463418918
# --------------------------------------------------
# Project Name: Group
# Role Name: Business Development Manager
# Applicant Name: Melissa
# Score: 6.432227833762068
# --------------------------------------------------
# Project Name: Group
# Role Name: Business Development Manager
# Applicant Name: Corey
# Score: 6.430962347291866
# --------------------------------------------------
# Project Name: Group
# Role Name: HR Officer
# Applicant Name: Robin
# Score: 8.430407864605447
# --------------------------------------------------
# Project Name: Group
# Role Name: HR Officer
# Applicant Name: Sean
# Score: 8.429982270224356
# --------------------------------------------------
# Project Name: Group
# Role Name: HR Officer
# Applicant Name: Cristina
# Score: 8.428335789471037
# --------------------------------------------------
# Project Name: Group
# Role Name: HR Officer
# Applicant Name: Jennifer
# Score: 8.427834356139106
# --------------------------------------------------
# Project Name: Group
# Role Name: HR Officer
# Applicant Name: Justin
# Score: 8.427701626924927
# --------------------------------------------------
# Project Name: Group
# Role Name: Security Engineer
# Applicant Name: Sara
# Score: 8.430248457576369
# --------------------------------------------------
# Project Name: Group
# Role Name: Security Engineer
# Applicant Name: Robin
# Score: 8.429410428676508
# --------------------------------------------------
# Project Name: Group
# Role Name: Security Engineer
# Applicant Name: Candace
# Score: 8.429278066739805
# --------------------------------------------------
# Project Name: Group
# Role Name: Security Engineer
# Applicant Name: Sean
# Score: 8.428917202914574
# --------------------------------------------------
# Project Name: Group
# Role Name: Security Engineer
# Applicant Name: Nathan
# Score: 8.428801000042423
# --------------------------------------------------
# Project Name: Group
# Role Name: Solution Architect
# Applicant Name: Barry
# Score: 7.678938849644479
# --------------------------------------------------
# Project Name: Group
# Role Name: Solution Architect
# Applicant Name: Kelly
# Score: 7.678678104686037
# --------------------------------------------------
# Project Name: Group
# Role Name: Solution Architect
# Applicant Name: Eddie
# Score: 7.677308086565425
# --------------------------------------------------
# Project Name: Group
# Role Name: Solution Architect
# Applicant Name: Jennifer
# Score: 7.427753712651592
# --------------------------------------------------
# Project Name: Group
# Role Name: Solution Architect
# Applicant Name: Maria
# Score: 7.427272112984433
# --------------------------------------------------
# Project Name: Inc
# Role Name: CX / Business Designer
# Applicant Name: Sara
# Score: 6.929919577208902
# --------------------------------------------------
# Project Name: Inc
# Role Name: CX / Business Designer
# Applicant Name: Melissa
# Score: 6.929443253488024
# --------------------------------------------------
# Project Name: Inc
# Role Name: CX / Business Designer
# Applicant Name: Robin
# Score: 6.929093352680564
# --------------------------------------------------
# Project Name: Inc
# Role Name: CX / Business Designer
# Applicant Name: Diane
# Score: 6.928756429044255
# --------------------------------------------------
# Project Name: Inc
# Role Name: CX / Business Designer
# Applicant Name: Sean
# Score: 6.928727238122633
# --------------------------------------------------
# Project Name: Inc
# Role Name: Data Scientist
# Applicant Name: Scott
# Score: 7.932094732792419
# --------------------------------------------------
# Project Name: Inc
# Role Name: Data Scientist
# Applicant Name: James
# Score: 7.931933617904196
# --------------------------------------------------
# Project Name: Inc
# Role Name: Data Scientist
# Applicant Name: Sara
# Score: 7.931905421098972
# --------------------------------------------------
# Project Name: Inc
# Role Name: Data Scientist
# Applicant Name: Carrie
# Score: 7.9315470713067056
# --------------------------------------------------
# Project Name: Inc
# Role Name: Data Scientist
# Applicant Name: Robin
# Score: 7.930978511123888
# --------------------------------------------------
# Project Name: Inc
# Role Name: HR Officer
# Applicant Name: Sean
# Score: 7.431166992257394
# --------------------------------------------------
# Project Name: Inc
# Role Name: HR Officer
# Applicant Name: Robin
# Score: 7.430995401413526
# --------------------------------------------------
# Project Name: Inc
# Role Name: HR Officer
# Applicant Name: Candace
# Score: 7.430658633392124
# --------------------------------------------------
# Project Name: Inc
# Role Name: HR Officer
# Applicant Name: Kayla
# Score: 7.430571884863484
# --------------------------------------------------
# Project Name: Inc
# Role Name: HR Officer
# Applicant Name: Nathan
# Score: 7.43036101268447
# --------------------------------------------------
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Applicant Name: Melissa
# Score: 7.930201802711143
# --------------------------------------------------
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Applicant Name: Sara
# Score: 7.430669556326246
# --------------------------------------------------
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Applicant Name: Brian
# Score: 7.430407858702881
# --------------------------------------------------
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Applicant Name: Raymond
# Score: 7.430158063992801
# --------------------------------------------------
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Applicant Name: Wendy
# Score: 7.430046304926442
# --------------------------------------------------
# Project Name: Inc
# Role Name: Project Manager
# Applicant Name: Gregory
# Score: 8.928544263365506
# --------------------------------------------------
# Project Name: Inc
# Role Name: Project Manager
# Applicant Name: James
# Score: 8.430001156870794
# --------------------------------------------------
# Project Name: Inc
# Role Name: Project Manager
# Applicant Name: Carrie
# Score: 8.429737908684183
# --------------------------------------------------
# Project Name: Inc
# Role Name: Project Manager
# Applicant Name: Melanie
# Score: 8.429280904529984
# --------------------------------------------------
# Project Name: Inc
# Role Name: Project Manager
# Applicant Name: Robin
# Score: 8.429206172574782
# --------------------------------------------------
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Applicant Name: Scott
# Score: 8.429989986067168
# --------------------------------------------------
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Applicant Name: Sara
# Score: 8.429505319726582
# --------------------------------------------------
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Applicant Name: Wendy
# Score: 8.429074951686284
# --------------------------------------------------
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Applicant Name: Patricia
# Score: 8.42893234239132
# --------------------------------------------------
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Applicant Name: Barry
# Score: 8.42886229218796
# --------------------------------------------------
# Project Name: Inc
# Role Name: Systems Test Engineer
# Applicant Name: Sara
# Score: 7.430640668223262
# --------------------------------------------------
# Project Name: Inc
# Role Name: Systems Test Engineer
# Applicant Name: Wendy
# Score: 7.4300908473829175
# --------------------------------------------------
# Project Name: Inc
# Role Name: Systems Test Engineer
# Applicant Name: Raymond
# Score: 7.429964175162876
# --------------------------------------------------
# Project Name: Inc
# Role Name: Systems Test Engineer
# Applicant Name: Barry
# Score: 7.4299520553288865
# --------------------------------------------------
# Project Name: Inc
# Role Name: Systems Test Engineer
# Applicant Name: Candace
# Score: 7.429793244248896
# --------------------------------------------------
# Project Name: Inc
# Role Name: Technical Product Manager
# Applicant Name: Sara
# Score: 7.431832717175327
# --------------------------------------------------
# Project Name: Inc
# Role Name: Technical Product Manager
# Applicant Name: Melissa
# Score: 7.431405154845384
# --------------------------------------------------
# Project Name: Inc
# Role Name: Technical Product Manager
# Applicant Name: Candace
# Score: 7.431213539555181
# --------------------------------------------------
# Project Name: Inc
# Role Name: Technical Product Manager
# Applicant Name: Robin
# Score: 7.431000777986042
# --------------------------------------------------
# Project Name: Inc
# Role Name: Technical Product Manager
# Applicant Name: Sean
# Score: 7.430681299972738
# --------------------------------------------------
# Project Name: PLC
# Role Name: Back-End Engineer
# Applicant Name: Raymond
# Score: 8.428895950777623
# --------------------------------------------------
# Project Name: PLC
# Role Name: Back-End Engineer
# Applicant Name: Brian
# Score: 8.428701920035968
# --------------------------------------------------
# Project Name: PLC
# Role Name: Back-End Engineer
# Applicant Name: Melissa
# Score: 8.42853696092448
# --------------------------------------------------
# Project Name: PLC
# Role Name: Back-End Engineer
# Applicant Name: Patricia
# Score: 8.428190073935356
# --------------------------------------------------
# Project Name: PLC
# Role Name: Back-End Engineer
# Applicant Name: Candace
# Score: 8.428034601221675
# --------------------------------------------------
# Project Name: PLC
# Role Name: Content Editor
# Applicant Name: Debra
# Score: 8.430237131215785
# --------------------------------------------------
# Project Name: PLC
# Role Name: Content Editor
# Applicant Name: Sara
# Score: 8.429446112335246
# --------------------------------------------------
# Project Name: PLC
# Role Name: Content Editor
# Applicant Name: Candace
# Score: 8.428713438879297
# --------------------------------------------------
# Project Name: PLC
# Role Name: Content Editor
# Applicant Name: Robin
# Score: 8.428601906972233
# --------------------------------------------------
# Project Name: PLC
# Role Name: Content Editor
# Applicant Name: Raymond
# Score: 8.42851589357145
# --------------------------------------------------
# Project Name: PLC
# Role Name: DevOps Engineer
# Applicant Name: Melissa
# Score: 7.430677990408623
# --------------------------------------------------
# Project Name: PLC
# Role Name: DevOps Engineer
# Applicant Name: Corey
# Score: 7.429324016983114
# --------------------------------------------------
# Project Name: PLC
# Role Name: DevOps Engineer
# Applicant Name: Lindsey
# Score: 7.42918725890926
# --------------------------------------------------
# Project Name: PLC
# Role Name: DevOps Engineer
# Applicant Name: James
# Score: 6.681214663984536
# --------------------------------------------------
# Project Name: PLC
# Role Name: DevOps Engineer
# Applicant Name: Kathy
# Score: 6.680791791000075
# --------------------------------------------------
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Applicant Name: Melissa
# Score: 8.430298553753408
# --------------------------------------------------
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Applicant Name: Wendy
# Score: 8.429670649611916
# --------------------------------------------------
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Applicant Name: Corey
# Score: 8.428317941709743
# --------------------------------------------------
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Applicant Name: Lindsey
# Score: 8.428166903750933
# --------------------------------------------------
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Applicant Name: Lance
# Score: 7.928933855349432
# --------------------------------------------------
# Project Name: PLC
# Role Name: Graphic Designer
# Applicant Name: Sara
# Score: 7.930146665927747
# --------------------------------------------------
# Project Name: PLC
# Role Name: Graphic Designer
# Applicant Name: Kimberly
# Score: 7.929321379950134
# --------------------------------------------------
# Project Name: PLC
# Role Name: Graphic Designer
# Applicant Name: Candace
# Score: 7.929302624503122
# --------------------------------------------------
# Project Name: PLC
# Role Name: Graphic Designer
# Applicant Name: Gregory
# Score: 7.92876784906929
# --------------------------------------------------
# Project Name: PLC
# Role Name: Graphic Designer
# Applicant Name: Nathan
# Score: 7.928650258923225
# --------------------------------------------------
# Project Name: PLC
# Role Name: Law Expert
# Applicant Name: Sara
# Score: 8.430678420678577
# --------------------------------------------------
# Project Name: PLC
# Role Name: Law Expert
# Applicant Name: Melissa
# Score: 8.429949804355436
# --------------------------------------------------
# Project Name: PLC
# Role Name: Law Expert
# Applicant Name: Robin
# Score: 8.429673669972074
# --------------------------------------------------
# Project Name: PLC
# Role Name: Law Expert
# Applicant Name: Sean
# Score: 8.42907357306351
# --------------------------------------------------
# Project Name: PLC
# Role Name: Law Expert
# Applicant Name: Dylan
# Score: 8.429062452730705
# --------------------------------------------------
# Project Name: PLC
# Role Name: UX Researcher
# Applicant Name: Melissa
# Score: 6.429147847143743
# --------------------------------------------------
# Project Name: PLC
# Role Name: UX Researcher
# Applicant Name: Candace
# Score: 6.428510978021389
# --------------------------------------------------
# Project Name: PLC
# Role Name: UX Researcher
# Applicant Name: Melanie
# Score: 6.428487736234178
# --------------------------------------------------
# Project Name: PLC
# Role Name: UX Researcher
# Applicant Name: Barry
# Score: 6.4284809699130925
# --------------------------------------------------
# Project Name: PLC
# Role Name: UX Researcher
# Applicant Name: Raymond
# Score: 6.428477482548342
# --------------------------------------------------

# %%
# test the compute_similarity function

# %%
text1 = "I am a Marketing professional with expertise in API Design, Android. My previous role was as a DevOps Engineer at Beard, Wheeler and Hoover in the Marketing industry where I gained 8 years of experience. Skills: API Design, Android, Brand Strategy"
text2 = "This role at LLC involves Technical Product Manager-related responsibilities in the ['IT', 'Finance', 'Healthcare', 'Education', 'Engineering', 'Marketing'] industry. We are looking for candidates with Fundraising, Brand Strategy, 3D Engineering skills and expertise. The role requires 8 years of experience."
compute_similarity(text1,text2)
# Out:
# 0.7248541582207213

# %%
#job recommendation

# %%
roles = conn.query("MATCH (r:Role) RETURN r.role_description, r.project_name, r.role_name")
applicants = conn.query("MATCH (a:Applicant) RETURN a.biography, a.personality_questions, a.UID")

biography_similarities = {}
question_similarities = {}

# %%
for role in roles:
    role_desc = role["r.role_description"]
    for applicant in applicants:
        applicant_bio = applicant["a.biography"]
        applicant_questions = applicant["a.personality_questions"]
        key = (role["r.project_name"], role["r.role_name"], applicant["a.UID"])

        biography_similarities[key] = compute_similarity(role_desc, applicant_bio)
        question_similarities[key] = compute_similarity(role_desc, applicant_questions)

# %%
for key, sim_score in biography_similarities.items():
    project_name, role_name, applicant_uid = key
    cql = f"""
    MATCH (r:Role {{project_name: '{project_name}', role_name: '{role_name}'}}),
          (a:Applicant {{UID: '{applicant_uid}'}})
    MERGE (r)-[:HAS_BIOGRAPHY_SIMILARITY {{score: {sim_score}}}]->(a)
    """
    conn.query(cql)

for key, sim_score in question_similarities.items():
    project_name, role_name, applicant_uid = key
    cql = f"""
    MATCH (r:Role {{project_name: '{project_name}', role_name: '{role_name}'}}),
          (a:Applicant {{UID: '{applicant_uid}'}})
    MERGE (r)-[:HAS_QUESTION_SIMILARITY {{score: {sim_score}}}]->(a)
    """
    conn.query(cql)

# %%
cql3 = """
MATCH (r:Role), (a:Applicant),
      (r)-[bio_rel:HAS_BIOGRAPHY_SIMILARITY]->(a),
      (r)-[ques_rel:HAS_QUESTION_SIMILARITY]->(a)

WITH r, a,
     size([x IN r.required_skills WHERE x IN a.skills]) AS matchedRequiredSkills,
     size(r.required_skills) AS totalRequiredSkills,
     CASE WHEN r.Location = a.Location THEN 1 ELSE 0 END AS locationMatch,
     CASE WHEN r.Industry = a.industry THEN 1 ELSE 0 END AS industryMatch,
     CASE WHEN r.Language = a.language THEN 1 ELSE 0 END AS languageMatch,
     CASE WHEN r.availability_date <= a.availability THEN 1 ELSE 0 END AS availabilityMatch,
     CASE WHEN r.min_available_hours_per_week <= a.working_hours THEN 1 ELSE 0 END AS hoursMatch,
     COALESCE(bio_rel.score, 0) * 0.25 AS biographySimilarityScore,
     COALESCE(ques_rel.score, 0) * 0.25 AS questionSimilarityScore

WHERE matchedRequiredSkills >= 0.8 * totalRequiredSkills

WITH a, r,
     1*matchedRequiredSkills + 1*locationMatch + 1*industryMatch + 1*languageMatch +
     1*availabilityMatch + 1*hoursMatch +
     size([x IN r.preferred_skills WHERE x IN a.skills]) * 0.5 +
     size([x IN r.tools WHERE x IN a.tools]) * 0.5 +
     CASE WHEN a.experience >= r.years_of_experience THEN 0.75 ELSE 0 END +
     biographySimilarityScore + questionSimilarityScore AS totalScore

ORDER BY a.UID, totalScore DESC

RETURN a.first_name AS applicant_name, r.project_name AS project_name, r.role_name AS role_name, totalScore AS score
ORDER BY applicant_name, score DESC;


"""

# %%
try:
    recommend_results = conn.query(cql3)
except Exception as e:
    print(f"Error executing CQL: {e}")


for record in recommend_results:
#     print(record)
    applicant_name = record.get('applicant_name', 'N/A')
    project_name = record.get('project_name', 'N/A')
    role_name = record.get('role_name', 'N/A')
    score = record.get('score', 'N/A')
    print(f"Applicant name: {applicant_name}\nProject Name: {project_name}\nRole Name: {role_name}\nScore: {score}\n{'-'*50}")
# Out:
# Applicant name: Aaron
# Project Name: Inc
# Role Name: Project Manager
# Score: 7.54652279875407
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: Inc
# Role Name: Data Scientist
# Score: 7.0480923213099
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: Group
# Role Name: HR Officer
# Score: 6.799283071646788
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: Group
# Role Name: Solution Architect
# Score: 6.798883944879322
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 6.796607361864254
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.795299238076024
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: PLC
# Role Name: Content Editor
# Score: 6.7951796902095
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: Group
# Role Name: Security Engineer
# Score: 6.795170643215261
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: PLC
# Role Name: Law Expert
# Score: 6.793285800519007
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 6.791768203865594
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Score: 6.787735608025382
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 6.296850504265501
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: PLC
# Role Name: Law Expert
# Score: 6.293285800519007
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: Inc
# Role Name: HR Officer
# Score: 5.798400470658864
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 5.797893551206081
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 5.792720692590055
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 5.791835083713175
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: Group
# Role Name: Business Development Manager
# Score: 5.297134680209697
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 5.29204157548148
# --------------------------------------------------
# Applicant name: Aaron
# Project Name: PLC
# Role Name: UX Researcher
# Score: 4.7966976381697215
# --------------------------------------------------
# Applicant name: Adam
# Project Name: Inc
# Role Name: Project Manager
# Score: 7.51855658625647
# --------------------------------------------------
# Applicant name: Adam
# Project Name: Inc
# Role Name: Data Scientist
# Score: 7.018819072612045
# --------------------------------------------------
# Applicant name: Adam
# Project Name: Group
# Role Name: HR Officer
# Score: 6.770974685868069
# --------------------------------------------------
# Applicant name: Adam
# Project Name: Group
# Role Name: Solution Architect
# Score: 6.770627054858563
# --------------------------------------------------
# Applicant name: Adam
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 6.7687826511659654
# --------------------------------------------------
# Applicant name: Adam
# Project Name: Group
# Role Name: Security Engineer
# Score: 6.767583696781047
# --------------------------------------------------
# Applicant name: Adam
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.767525227445287
# --------------------------------------------------
# Applicant name: Adam
# Project Name: PLC
# Role Name: Content Editor
# Score: 6.767159275733907
# --------------------------------------------------
# Applicant name: Adam
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 6.765325820180254
# --------------------------------------------------
# Applicant name: Adam
# Project Name: PLC
# Role Name: Law Expert
# Score: 6.764280712138455
# --------------------------------------------------
# Applicant name: Adam
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Score: 6.7601187555605975
# --------------------------------------------------
# Applicant name: Adam
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 6.514245839827277
# --------------------------------------------------
# Applicant name: Adam
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 6.268947109330855
# --------------------------------------------------
# Applicant name: Adam
# Project Name: PLC
# Role Name: Law Expert
# Score: 6.264280712138455
# --------------------------------------------------
# Applicant name: Adam
# Project Name: Inc
# Role Name: HR Officer
# Score: 5.771173977859039
# --------------------------------------------------
# Applicant name: Adam
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 5.7702133587801985
# --------------------------------------------------
# Applicant name: Adam
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 5.765229250118137
# --------------------------------------------------
# Applicant name: Adam
# Project Name: Group
# Role Name: Business Development Manager
# Score: 5.2704827585863985
# --------------------------------------------------
# Applicant name: Adam
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 5.264427214501106
# --------------------------------------------------
# Applicant name: Adam
# Project Name: PLC
# Role Name: UX Researcher
# Score: 4.76855829065143
# --------------------------------------------------
# Applicant name: Alexandra
# Project Name: Inc
# Role Name: Project Manager
# Score: 8.571314434719536
# --------------------------------------------------
# Applicant name: Alexandra
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Score: 8.567020450805407
# --------------------------------------------------
# Applicant name: Alexandra
# Project Name: Inc
# Role Name: Data Scientist
# Score: 8.073515702914795
# --------------------------------------------------
# Applicant name: Alexandra
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.81990309841906
# --------------------------------------------------
# Applicant name: Alexandra
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 7.56944851639399
# --------------------------------------------------
# Applicant name: Alexandra
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.31990309841906
# --------------------------------------------------
# Applicant name: Alexandra
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.0698068378240535
# --------------------------------------------------
# Applicant name: Alexandra
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.822859788245786
# --------------------------------------------------
# Applicant name: Alexandra
# Project Name: Group
# Role Name: Solution Architect
# Score: 6.8222158505819355
# --------------------------------------------------
# Applicant name: Alexandra
# Project Name: PLC
# Role Name: UX Researcher
# Score: 5.821433727295464
# --------------------------------------------------
# Applicant name: Alexandra
# Project Name: Group
# Role Name: Business Development Manager
# Score: 5.323740740129681
# --------------------------------------------------
# Applicant name: Alison
# Project Name: PLC
# Role Name: Content Editor
# Score: 7.790868043096728
# --------------------------------------------------
# Applicant name: Alison
# Project Name: Group
# Role Name: Security Engineer
# Score: 7.789876801034169
# --------------------------------------------------
# Applicant name: Alison
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.290922135206499
# --------------------------------------------------
# Applicant name: Alison
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 6.290884571079106
# --------------------------------------------------
# Applicant name: Alison
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 6.286863058798871
# --------------------------------------------------
# Applicant name: Alison
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 5.79363578318071
# --------------------------------------------------
# Applicant name: Alison
# Project Name: Group
# Role Name: Business Development Manager
# Score: 5.293351212343276
# --------------------------------------------------
# Applicant name: Alison
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 5.288694340216801
# --------------------------------------------------
# Applicant name: Alison
# Project Name: PLC
# Role Name: UX Researcher
# Score: 4.791941322236465
# --------------------------------------------------
# Applicant name: Amber
# Project Name: Inc
# Role Name: Project Manager
# Score: 7.548394116466935
# --------------------------------------------------
# Applicant name: Amber
# Project Name: Inc
# Role Name: Data Scientist
# Score: 7.049359553797801
# --------------------------------------------------
# Applicant name: Amber
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.797505878329837
# --------------------------------------------------
# Applicant name: Amber
# Project Name: PLC
# Role Name: Law Expert
# Score: 6.795423100473194
# --------------------------------------------------
# Applicant name: Amber
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Score: 6.789617518369235
# --------------------------------------------------
# Applicant name: Amber
# Project Name: Group
# Role Name: Solution Architect
# Score: 5.799655561679711
# --------------------------------------------------
# Applicant name: Amber
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 5.7947196268699335
# --------------------------------------------------
# Applicant name: Amber
# Project Name: Group
# Role Name: Business Development Manager
# Score: 5.2988922049593015
# --------------------------------------------------
# Applicant name: Amber
# Project Name: PLC
# Role Name: Law Expert
# Score: 5.295423100473194
# --------------------------------------------------
# Applicant name: Amber
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 5.293383106219894
# --------------------------------------------------
# Applicant name: Amber
# Project Name: PLC
# Role Name: UX Researcher
# Score: 3.79796976297085
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: PLC
# Role Name: Content Editor
# Score: 8.542301031447833
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 8.538729088087077
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Score: 8.534609968714866
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: Inc
# Role Name: Data Scientist
# Score: 8.04438340356805
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: Group
# Role Name: Security Engineer
# Score: 7.7919050692760505
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 7.543819247975543
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: Inc
# Role Name: Project Manager
# Score: 7.543018769125203
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 7.043365553111555
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: Group
# Role Name: HR Officer
# Score: 6.795935969183882
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: Group
# Role Name: Solution Architect
# Score: 6.795249393511029
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.792457490165821
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: PLC
# Role Name: Law Expert
# Score: 6.79023794143189
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: Inc
# Role Name: HR Officer
# Score: 6.545744309612413
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 6.544963783004345
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 6.539727081172958
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 6.538885988445169
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: PLC
# Role Name: Law Expert
# Score: 6.29023794143189
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 6.2889118602845135
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: Group
# Role Name: Business Development Manager
# Score: 6.044250382638095
# --------------------------------------------------
# Applicant name: Ashlee
# Project Name: PLC
# Role Name: UX Researcher
# Score: 5.54372936133674
# --------------------------------------------------
# Applicant name: Audrey
# Project Name: Inc
# Role Name: Project Manager
# Score: 7.571933565274107
# --------------------------------------------------
# Applicant name: Audrey
# Project Name: Inc
# Role Name: Data Scientist
# Score: 7.074609521208011
# --------------------------------------------------
# Applicant name: Audrey
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 7.07080747947264
# --------------------------------------------------
# Applicant name: Audrey
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 6.572309789330908
# --------------------------------------------------
# Applicant name: Audrey
# Project Name: PLC
# Role Name: UX Researcher
# Score: 4.820859386609798
# --------------------------------------------------
# Applicant name: Austin
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Score: 8.054074883617753
# --------------------------------------------------
# Applicant name: Austin
# Project Name: Inc
# Role Name: Data Scientist
# Score: 7.559410013668988
# --------------------------------------------------
# Applicant name: Austin
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.558317029629293
# --------------------------------------------------
# Applicant name: Austin
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 7.556201752186692
# --------------------------------------------------
# Applicant name: Austin
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.3064243219107405
# --------------------------------------------------
# Applicant name: Austin
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 7.055698010390967
# --------------------------------------------------
# Applicant name: Austin
# Project Name: Inc
# Role Name: HR Officer
# Score: 6.310483659689664
# --------------------------------------------------
# Applicant name: Austin
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 5.810368836960437
# --------------------------------------------------
# Applicant name: Barry
# Project Name: Inc
# Role Name: Project Manager
# Score: 8.504940753606824
# --------------------------------------------------
# Applicant name: Barry
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Score: 8.496070948411097
# --------------------------------------------------
# Applicant name: Barry
# Project Name: Inc
# Role Name: Data Scientist
# Score: 8.004814745525284
# --------------------------------------------------
# Applicant name: Barry
# Project Name: Group
# Role Name: Solution Architect
# Score: 7.757211819332332
# --------------------------------------------------
# Applicant name: Barry
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.75094592101119
# --------------------------------------------------
# Applicant name: Barry
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 7.501119020076196
# --------------------------------------------------
# Applicant name: Barry
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.25094592101119
# --------------------------------------------------
# Applicant name: Barry
# Project Name: Group
# Role Name: Business Development Manager
# Score: 7.006398616056097
# --------------------------------------------------
# Applicant name: Barry
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.000267357674005
# --------------------------------------------------
# Applicant name: Barry
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.753569180920446
# --------------------------------------------------
# Applicant name: Barry
# Project Name: PLC
# Role Name: UX Researcher
# Score: 6.505245557757561
# --------------------------------------------------
# Applicant name: Brandon
# Project Name: Group
# Role Name: Security Engineer
# Score: 7.767796100957793
# --------------------------------------------------
# Applicant name: Brandon
# Project Name: PLC
# Role Name: Content Editor
# Score: 6.768407192265469
# --------------------------------------------------
# Applicant name: Brandon
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.269090781909088
# --------------------------------------------------
# Applicant name: Brandon
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 6.268947532342504
# --------------------------------------------------
# Applicant name: Brandon
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 6.266957770962015
# --------------------------------------------------
# Applicant name: Brandon
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 5.770144178061049
# --------------------------------------------------
# Applicant name: Brandon
# Project Name: Group
# Role Name: Business Development Manager
# Score: 5.271585090362479
# --------------------------------------------------
# Applicant name: Brandon
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 5.266736481892879
# --------------------------------------------------
# Applicant name: Brandon
# Project Name: PLC
# Role Name: UX Researcher
# Score: 3.767888617665391
# --------------------------------------------------
# Applicant name: Brenda
# Project Name: PLC
# Role Name: Content Editor
# Score: 8.043676726879427
# --------------------------------------------------
# Applicant name: Brenda
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Score: 8.036386974079115
# --------------------------------------------------
# Applicant name: Brenda
# Project Name: Group
# Role Name: Security Engineer
# Score: 7.793531238252464
# --------------------------------------------------
# Applicant name: Brenda
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 7.545171282982688
# --------------------------------------------------
# Applicant name: Brenda
# Project Name: Inc
# Role Name: Project Manager
# Score: 7.043957849828993
# --------------------------------------------------
# Applicant name: Brenda
# Project Name: Group
# Role Name: Solution Architect
# Score: 6.297051702024967
# --------------------------------------------------
# Applicant name: Brenda
# Project Name: PLC
# Role Name: Law Expert
# Score: 6.292154409234226
# --------------------------------------------------
# Applicant name: Brenda
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 6.290186596921487
# --------------------------------------------------
# Applicant name: Brenda
# Project Name: Inc
# Role Name: HR Officer
# Score: 5.79711600244687
# --------------------------------------------------
# Applicant name: Brenda
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 5.7950103136596525
# --------------------------------------------------
# Applicant name: Brenda
# Project Name: Group
# Role Name: Business Development Manager
# Score: 5.5454322627640105
# --------------------------------------------------
# Applicant name: Brenda
# Project Name: PLC
# Role Name: UX Researcher
# Score: 5.044844827177945
# --------------------------------------------------
# Applicant name: Brent
# Project Name: PLC
# Role Name: Law Expert
# Score: 8.533497159197262
# --------------------------------------------------
# Applicant name: Brent
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 8.531744032375608
# --------------------------------------------------
# Applicant name: Brent
# Project Name: Group
# Role Name: HR Officer
# Score: 8.039258373121323
# --------------------------------------------------
# Applicant name: Brent
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 8.03732252401984
# --------------------------------------------------
# Applicant name: Brent
# Project Name: PLC
# Role Name: Content Editor
# Score: 8.035678815356187
# --------------------------------------------------
# Applicant name: Brent
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 7.535952830092414
# --------------------------------------------------
# Applicant name: Brent
# Project Name: Inc
# Role Name: HR Officer
# Score: 7.038906064434894
# --------------------------------------------------
# Applicant name: Brent
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 7.032036851386346
# --------------------------------------------------
# Applicant name: Brent
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 6.538404199376186
# --------------------------------------------------
# Applicant name: Brent
# Project Name: PLC
# Role Name: Law Expert
# Score: 6.533497159197263
# --------------------------------------------------
# Applicant name: Brent
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 6.532322269455789
# --------------------------------------------------
# Applicant name: Brent
# Project Name: Group
# Role Name: Business Development Manager
# Score: 5.5377403946649295
# --------------------------------------------------
# Applicant name: Brent
# Project Name: PLC
# Role Name: UX Researcher
# Score: 5.037148489460388
# --------------------------------------------------
# Applicant name: Brian
# Project Name: PLC
# Role Name: Content Editor
# Score: 8.535496433841184
# --------------------------------------------------
# Applicant name: Brian
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 8.506075819091198
# --------------------------------------------------
# Applicant name: Brian
# Project Name: PLC
# Role Name: Content Editor
# Score: 8.009081804563467
# --------------------------------------------------
# Applicant name: Brian
# Project Name: Group
# Role Name: Security Engineer
# Score: 7.78569362197316
# --------------------------------------------------
# Applicant name: Brian
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.75597347772221
# --------------------------------------------------
# Applicant name: Brian
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 7.510841019263139
# --------------------------------------------------
# Applicant name: Brian
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.505562248635226
# --------------------------------------------------
# Applicant name: Brian
# Project Name: Group
# Role Name: HR Officer
# Score: 7.262767161699976
# --------------------------------------------------
# Applicant name: Brian
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 7.037168391331973
# --------------------------------------------------
# Applicant name: Brian
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.75874200817064
# --------------------------------------------------
# Applicant name: Brian
# Project Name: PLC
# Role Name: Law Expert
# Score: 6.75597347772221
# --------------------------------------------------
# Applicant name: Brian
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 6.538189532113871
# --------------------------------------------------
# Applicant name: Brian
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.285368259616758
# --------------------------------------------------
# Applicant name: Brian
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 6.281986764724089
# --------------------------------------------------
# Applicant name: Brian
# Project Name: Inc
# Role Name: HR Officer
# Score: 6.262706219193542
# --------------------------------------------------
# Applicant name: Brian
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 6.255421118977839
# --------------------------------------------------
# Applicant name: Brian
# Project Name: Group
# Role Name: Business Development Manager
# Score: 6.0367515250085395
# --------------------------------------------------
# Applicant name: Brian
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 6.033021275230092
# --------------------------------------------------
# Applicant name: Brian
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 5.761650719105272
# --------------------------------------------------
# Applicant name: Brian
# Project Name: PLC
# Role Name: UX Researcher
# Score: 5.536621435648073
# --------------------------------------------------
# Applicant name: Brian
# Project Name: PLC
# Role Name: UX Researcher
# Score: 5.2602976679293425
# --------------------------------------------------
# Applicant name: Brian
# Project Name: Group
# Role Name: Business Development Manager
# Score: 4.761564223230763
# --------------------------------------------------
# Applicant name: Brittany
# Project Name: Inc
# Role Name: Project Manager
# Score: 8.529177224105577
# --------------------------------------------------
# Applicant name: Brittany
# Project Name: Inc
# Role Name: Data Scientist
# Score: 8.030207135019388
# --------------------------------------------------
# Applicant name: Brittany
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 8.02358302203712
# --------------------------------------------------
# Applicant name: Brittany
# Project Name: Group
# Role Name: HR Officer
# Score: 7.782150705120198
# --------------------------------------------------
# Applicant name: Brittany
# Project Name: Group
# Role Name: Security Engineer
# Score: 7.777796680541854
# --------------------------------------------------
# Applicant name: Brittany
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 7.025514974466116
# --------------------------------------------------
# Applicant name: Brittany
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.023746077827829
# --------------------------------------------------
# Applicant name: Brittany
# Project Name: Inc
# Role Name: HR Officer
# Score: 6.781663805419809
# --------------------------------------------------
# Applicant name: Brittany
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 6.279911861177982
# --------------------------------------------------
# Applicant name: Brittany
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 6.279305926235602
# --------------------------------------------------
# Applicant name: Brittany
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 5.7808171641515305
# --------------------------------------------------
# Applicant name: Brittany
# Project Name: PLC
# Role Name: UX Researcher
# Score: 5.779283916228495
# --------------------------------------------------
# Applicant name: Candace
# Project Name: Inc
# Role Name: Project Manager
# Score: 8.53009517574417
# --------------------------------------------------
# Applicant name: Candace
# Project Name: PLC
# Role Name: Content Editor
# Score: 8.529484242862871
# --------------------------------------------------
# Applicant name: Candace
# Project Name: Group
# Role Name: Security Engineer
# Score: 8.52932332731231
# --------------------------------------------------
# Applicant name: Candace
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 8.52447547936828
# --------------------------------------------------
# Applicant name: Candace
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Score: 8.520521748558975
# --------------------------------------------------
# Applicant name: Candace
# Project Name: Inc
# Role Name: Data Scientist
# Score: 8.031653238562416
# --------------------------------------------------
# Applicant name: Candace
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 8.031007184819355
# --------------------------------------------------
# Applicant name: Candace
# Project Name: Group
# Role Name: HR Officer
# Score: 7.784435139927523
# --------------------------------------------------
# Applicant name: Candace
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.777351466304248
# --------------------------------------------------
# Applicant name: Candace
# Project Name: Inc
# Role Name: HR Officer
# Score: 7.532863893840996
# --------------------------------------------------
# Applicant name: Candace
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 7.530821458280992
# --------------------------------------------------
# Applicant name: Candace
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 7.528866970794613
# --------------------------------------------------
# Applicant name: Candace
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 7.52628498306655
# --------------------------------------------------
# Applicant name: Candace
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.524315982340981
# --------------------------------------------------
# Applicant name: Candace
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.277351466304248
# --------------------------------------------------
# Applicant name: Candace
# Project Name: Group
# Role Name: Solution Architect
# Score: 6.783951825316958
# --------------------------------------------------
# Applicant name: Candace
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 6.532139345184631
# --------------------------------------------------
# Applicant name: Candace
# Project Name: PLC
# Role Name: UX Researcher
# Score: 6.531412333946183
# --------------------------------------------------
# Applicant name: Candace
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 6.27447515047473
# --------------------------------------------------
# Applicant name: Candace
# Project Name: Group
# Role Name: Business Development Manager
# Score: 6.03041216566106
# --------------------------------------------------
# Applicant name: Carrie
# Project Name: Inc
# Role Name: Project Manager
# Score: 8.514968743395412
# --------------------------------------------------
# Applicant name: Carrie
# Project Name: Inc
# Role Name: Data Scientist
# Score: 8.01614645081518
# --------------------------------------------------
# Applicant name: Carrie
# Project Name: Group
# Role Name: HR Officer
# Score: 7.767900829739065
# --------------------------------------------------
# Applicant name: Carrie
# Project Name: Group
# Role Name: Security Engineer
# Score: 7.763838450971699
# --------------------------------------------------
# Applicant name: Carrie
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 7.016798319790656
# --------------------------------------------------
# Applicant name: Carrie
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 7.011390367887267
# --------------------------------------------------
# Applicant name: Carrie
# Project Name: Inc
# Role Name: HR Officer
# Score: 6.768923779508973
# --------------------------------------------------
# Applicant name: Carrie
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 6.2657169985373455
# --------------------------------------------------
# Applicant name: Carrie
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 6.012498626859758
# --------------------------------------------------
# Applicant name: Carrie
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 6.011640945799104
# --------------------------------------------------
# Applicant name: Carrie
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 5.7680357812968825
# --------------------------------------------------
# Applicant name: Carrie
# Project Name: PLC
# Role Name: UX Researcher
# Score: 4.765601872673421
# --------------------------------------------------
# Applicant name: Corey
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 8.531852283825557
# --------------------------------------------------
# Applicant name: Corey
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 8.52801226200858
# --------------------------------------------------
# Applicant name: Corey
# Project Name: PLC
# Role Name: Law Expert
# Score: 8.52725854680259
# --------------------------------------------------
# Applicant name: Corey
# Project Name: Group
# Role Name: HR Officer
# Score: 8.034112174229229
# --------------------------------------------------
# Applicant name: Corey
# Project Name: PLC
# Role Name: Content Editor
# Score: 8.030193005018743
# --------------------------------------------------
# Applicant name: Corey
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 7.533244572519928
# --------------------------------------------------
# Applicant name: Corey
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 7.530388468518031
# --------------------------------------------------
# Applicant name: Corey
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.527258546802591
# --------------------------------------------------
# Applicant name: Corey
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.526991787612037
# --------------------------------------------------
# Applicant name: Corey
# Project Name: Inc
# Role Name: HR Officer
# Score: 7.034099487686715
# --------------------------------------------------
# Applicant name: Corey
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 7.027220225547632
# --------------------------------------------------
# Applicant name: Corey
# Project Name: Group
# Role Name: Business Development Manager
# Score: 6.533267541830234
# --------------------------------------------------
# Applicant name: Corey
# Project Name: PLC
# Role Name: UX Researcher
# Score: 6.03241907052861
# --------------------------------------------------
# Applicant name: Cristina
# Project Name: Group
# Role Name: HR Officer
# Score: 8.502013578427047
# --------------------------------------------------
# Applicant name: Cristina
# Project Name: Inc
# Role Name: Project Manager
# Score: 8.498939717053785
# --------------------------------------------------
# Applicant name: Cristina
# Project Name: Group
# Role Name: Security Engineer
# Score: 8.497779790834393
# --------------------------------------------------
# Applicant name: Cristina
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 8.000209194590647
# --------------------------------------------------
# Applicant name: Cristina
# Project Name: Inc
# Role Name: Data Scientist
# Score: 8.000051372320677
# --------------------------------------------------
# Applicant name: Cristina
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 7.995036509262686
# --------------------------------------------------
# Applicant name: Cristina
# Project Name: Inc
# Role Name: HR Officer
# Score: 7.501480429813868
# --------------------------------------------------
# Applicant name: Cristina
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 7.000713638915673
# --------------------------------------------------
# Applicant name: Cristina
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 6.995318301487292
# --------------------------------------------------
# Applicant name: Cristina
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 6.995254184318595
# --------------------------------------------------
# Applicant name: Cristina
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 6.501459431732323
# --------------------------------------------------
# Applicant name: Cristina
# Project Name: PLC
# Role Name: UX Researcher
# Score: 6.499678623599706
# --------------------------------------------------
# Applicant name: Dawn
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 7.536861572014584
# --------------------------------------------------
# Applicant name: Dawn
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 7.535877212254235
# --------------------------------------------------
# Applicant name: Dawn
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.533677732059766
# --------------------------------------------------
# Applicant name: Dawn
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 7.53314609978891
# --------------------------------------------------
# Applicant name: Dawn
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.532032862362701
# --------------------------------------------------
# Applicant name: Dawn
# Project Name: Group
# Role Name: HR Officer
# Score: 7.039426426623285
# --------------------------------------------------
# Applicant name: Dawn
# Project Name: PLC
# Role Name: Content Editor
# Score: 7.035524441918688
# --------------------------------------------------
# Applicant name: Dawn
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 7.032723026962915
# --------------------------------------------------
# Applicant name: Dawn
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 6.537767518807225
# --------------------------------------------------
# Applicant name: Dawn
# Project Name: PLC
# Role Name: Law Expert
# Score: 6.533677732059766
# --------------------------------------------------
# Applicant name: Dawn
# Project Name: Inc
# Role Name: HR Officer
# Score: 6.03840452896004
# --------------------------------------------------
# Applicant name: Dawn
# Project Name: Group
# Role Name: Business Development Manager
# Score: 5.53681584689921
# --------------------------------------------------
# Applicant name: Dawn
# Project Name: PLC
# Role Name: UX Researcher
# Score: 5.035987499474293
# --------------------------------------------------
# Applicant name: Debra
# Project Name: PLC
# Role Name: Content Editor
# Score: 8.531371063171921
# --------------------------------------------------
# Applicant name: Debra
# Project Name: Group
# Role Name: Security Engineer
# Score: 7.780825447886648
# --------------------------------------------------
# Applicant name: Debra
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 7.032675020051694
# --------------------------------------------------
# Applicant name: Debra
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 6.533979770925199
# --------------------------------------------------
# Applicant name: Debra
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.280569010064066
# --------------------------------------------------
# Applicant name: Debra
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 6.276492430616622
# --------------------------------------------------
# Applicant name: Debra
# Project Name: Group
# Role Name: Business Development Manager
# Score: 6.032225680363656
# --------------------------------------------------
# Applicant name: Debra
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 6.028033700803467
# --------------------------------------------------
# Applicant name: Debra
# Project Name: PLC
# Role Name: UX Researcher
# Score: 5.533003318337091
# --------------------------------------------------
# Applicant name: Diane
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 7.532736028960574
# --------------------------------------------------
# Applicant name: Diane
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 7.531000960894788
# --------------------------------------------------
# Applicant name: Diane
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 7.527204105847508
# --------------------------------------------------
# Applicant name: Diane
# Project Name: PLC
# Role Name: Content Editor
# Score: 7.031429491971216
# --------------------------------------------------
# Applicant name: Diane
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 7.02764549450559
# --------------------------------------------------
# Applicant name: Diane
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 6.5340258102899424
# --------------------------------------------------
# Applicant name: Diane
# Project Name: PLC
# Role Name: Law Expert
# Score: 6.529603674302441
# --------------------------------------------------
# Applicant name: Diane
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 6.5271159315543965
# --------------------------------------------------
# Applicant name: Diane
# Project Name: Group
# Role Name: HR Officer
# Score: 6.035536195432053
# --------------------------------------------------
# Applicant name: Diane
# Project Name: Group
# Role Name: Business Development Manager
# Score: 5.532397098251819
# --------------------------------------------------
# Applicant name: Diane
# Project Name: Inc
# Role Name: HR Officer
# Score: 5.034543136937889
# --------------------------------------------------
# Applicant name: Diane
# Project Name: PLC
# Role Name: Law Expert
# Score: 4.779603674302441
# --------------------------------------------------
# Applicant name: Diane
# Project Name: PLC
# Role Name: UX Researcher
# Score: 4.033053251778114
# --------------------------------------------------
# Applicant name: Donald
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 7.558051318496481
# --------------------------------------------------
# Applicant name: Donald
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.555772455647968
# --------------------------------------------------
# Applicant name: Donald
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 6.054072913949401
# --------------------------------------------------
# Applicant name: Donald
# Project Name: PLC
# Role Name: Law Expert
# Score: 5.805772455647968
# --------------------------------------------------
# Applicant name: Donald
# Project Name: Group
# Role Name: Business Development Manager
# Score: 5.559048863313215
# --------------------------------------------------
# Applicant name: Donald
# Project Name: PLC
# Role Name: UX Researcher
# Score: 5.057752188267591
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: PLC
# Role Name: Content Editor
# Score: 8.545052323746427
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: Group
# Role Name: Security Engineer
# Score: 8.545042310718328
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: PLC
# Role Name: Law Expert
# Score: 8.544552202013232
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Score: 8.537849710130208
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: Inc
# Role Name: Data Scientist
# Score: 8.047682390145269
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: Group
# Role Name: HR Officer
# Score: 7.548674353177085
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 7.546768920393337
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 7.545651851617733
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: Inc
# Role Name: Project Manager
# Score: 7.545580044719853
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 7.541233138020557
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 7.045841125474547
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 7.041178334860258
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: Inc
# Role Name: HR Officer
# Score: 6.548388904994157
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 6.547328104225491
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 6.542904140531659
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 6.541529935726467
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: Group
# Role Name: Business Development Manager
# Score: 6.046904275490309
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: Group
# Role Name: Solution Architect
# Score: 5.797710402946547
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: PLC
# Role Name: Law Expert
# Score: 5.294552202013232
# --------------------------------------------------
# Applicant name: Dylan
# Project Name: PLC
# Role Name: UX Researcher
# Score: 4.5446481796508245
# --------------------------------------------------
# Applicant name: Eddie
# Project Name: Inc
# Role Name: Project Manager
# Score: 8.547529860751387
# --------------------------------------------------
# Applicant name: Eddie
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Score: 8.539631942833092
# --------------------------------------------------
# Applicant name: Eddie
# Project Name: Inc
# Role Name: Data Scientist
# Score: 8.049321426534895
# --------------------------------------------------
# Applicant name: Eddie
# Project Name: Group
# Role Name: Solution Architect
# Score: 7.800587888853219
# --------------------------------------------------
# Applicant name: Eddie
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.795158608645601
# --------------------------------------------------
# Applicant name: Eddie
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 7.544322953117399
# --------------------------------------------------
# Applicant name: Eddie
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.295158608645601
# --------------------------------------------------
# Applicant name: Eddie
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.043168347040115
# --------------------------------------------------
# Applicant name: Eddie
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.796772934131551
# --------------------------------------------------
# Applicant name: Eddie
# Project Name: Group
# Role Name: Business Development Manager
# Score: 6.298661305421889
# --------------------------------------------------
# Applicant name: Eddie
# Project Name: PLC
# Role Name: UX Researcher
# Score: 5.798889081303228
# --------------------------------------------------
# Applicant name: Eric
# Project Name: PLC
# Role Name: Content Editor
# Score: 8.515419842298426
# --------------------------------------------------
# Applicant name: Eric
# Project Name: Group
# Role Name: Security Engineer
# Score: 7.764212593210037
# --------------------------------------------------
# Applicant name: Eric
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 7.2665193143739755
# --------------------------------------------------
# Applicant name: Eric
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 7.0115172299694954
# --------------------------------------------------
# Applicant name: Eric
# Project Name: PLC
# Role Name: UX Researcher
# Score: 6.516693047729727
# --------------------------------------------------
# Applicant name: Eric
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.264896240452469
# --------------------------------------------------
# Applicant name: Eric
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 6.261080890603494
# --------------------------------------------------
# Applicant name: Eric
# Project Name: Group
# Role Name: Business Development Manager
# Score: 6.016235034440493
# --------------------------------------------------
# Applicant name: Eric
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 5.7679373341562235
# --------------------------------------------------
# Applicant name: Ernest
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.781408457598629
# --------------------------------------------------
# Applicant name: Ernest
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 7.534666100481734
# --------------------------------------------------
# Applicant name: Ernest
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.529131530640785
# --------------------------------------------------
# Applicant name: Ernest
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 7.528182540232117
# --------------------------------------------------
# Applicant name: Ernest
# Project Name: PLC
# ...
# Applicant name: Sean
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 7.534994215159218
# --------------------------------------------------
# Applicant name: Sean
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.533486035563147
# --------------------------------------------------
# Applicant name: Sean
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.286206384581281
# --------------------------------------------------
# Applicant name: Sean
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 7.033675999290817
# --------------------------------------------------
# Applicant name: Sean
# Project Name: Group
# Role Name: Solution Architect
# Score: 6.790369999626755
# --------------------------------------------------
# Applicant name: Sean
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 6.540488066110017
# --------------------------------------------------
# Applicant name: Sean
# Project Name: PLC
# Role Name: UX Researcher
# Score: 6.538275462853995
# --------------------------------------------------
# Applicant name: Sean
# Project Name: Group
# Role Name: Business Development Manager
# Score: 6.039108484193551
# --------------------------------------------------
# Applicant name: Shelly
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 8.013863807075943
# --------------------------------------------------
# Applicant name: Shelly
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Score: 8.010412984569882
# --------------------------------------------------
# Applicant name: Shelly
# Project Name: Inc
# Role Name: Data Scientist
# Score: 7.519283725179686
# --------------------------------------------------
# Applicant name: Shelly
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 7.5144824218507855
# --------------------------------------------------
# Applicant name: Shelly
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.513552524610683
# --------------------------------------------------
# Applicant name: Shelly
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.26557213916209
# --------------------------------------------------
# Applicant name: Shelly
# Project Name: Inc
# Role Name: HR Officer
# Score: 6.270468051499513
# --------------------------------------------------
# Applicant name: Shelly
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 5.770022128252206
# --------------------------------------------------
# Applicant name: Steven
# Project Name: PLC
# Role Name: Content Editor
# Score: 7.526691390631408
# --------------------------------------------------
# Applicant name: Steven
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 7.029224432179079
# --------------------------------------------------
# Applicant name: Steven
# Project Name: Group
# Role Name: Security Engineer
# Score: 6.776986674309132
# --------------------------------------------------
# Applicant name: Steven
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 6.530211615563327
# --------------------------------------------------
# Applicant name: Steven
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.276624617997129
# --------------------------------------------------
# Applicant name: Steven
# Project Name: Group
# Role Name: Business Development Manager
# Score: 6.027945979096414
# --------------------------------------------------
# Applicant name: Steven
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 6.023914687906523
# --------------------------------------------------
# Applicant name: Steven
# Project Name: PLC
# Role Name: UX Researcher
# Score: 5.528951160661361
# --------------------------------------------------
# Applicant name: Steven
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 5.273715136574673
# --------------------------------------------------
# Applicant name: Tanya
# Project Name: Group
# Role Name: Security Engineer
# Score: 7.794318237624114
# --------------------------------------------------
# Applicant name: Tanya
# Project Name: PLC
# Role Name: Content Editor
# Score: 7.544837062892304
# --------------------------------------------------
# Applicant name: Tanya
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 7.046058624945439
# --------------------------------------------------
# Applicant name: Tanya
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 6.5472860920062965
# --------------------------------------------------
# Applicant name: Tanya
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.294864267480494
# --------------------------------------------------
# Applicant name: Tanya
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 6.290920132093989
# --------------------------------------------------
# Applicant name: Tanya
# Project Name: Group
# Role Name: Business Development Manager
# Score: 6.046329935493723
# --------------------------------------------------
# Applicant name: Tanya
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 6.042158406053122
# --------------------------------------------------
# Applicant name: Tanya
# Project Name: PLC
# Role Name: UX Researcher
# Score: 4.545719205538845
# --------------------------------------------------
# Applicant name: Timothy
# Project Name: PLC
# Role Name: Content Editor
# Score: 8.546678088012174
# --------------------------------------------------
# Applicant name: Timothy
# Project Name: Group
# Role Name: Security Engineer
# Score: 7.795575547329412
# --------------------------------------------------
# Applicant name: Timothy
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.298087096360146
# --------------------------------------------------
# Applicant name: Timothy
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 6.297910010234386
# --------------------------------------------------
# Applicant name: Timothy
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 6.29500652373266
# --------------------------------------------------
# Applicant name: Timothy
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 6.043945090419044
# --------------------------------------------------
# Applicant name: Timothy
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 5.79921061290412
# --------------------------------------------------
# Applicant name: Timothy
# Project Name: Group
# Role Name: Business Development Manager
# Score: 5.298756738923156
# --------------------------------------------------
# Applicant name: Timothy
# Project Name: PLC
# Role Name: UX Researcher
# Score: 4.7972407122716865
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: Group
# Role Name: Security Engineer
# Score: 8.558593286894354
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: PLC
# Role Name: Law Expert
# Score: 8.557361139289412
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Score: 8.555006319769033
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: Inc
# Role Name: Data Scientist
# Score: 8.061146913505313
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 8.059713572100383
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 7.560894195218924
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: Group
# Role Name: HR Officer
# Score: 7.560649209669805
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 7.559949563455673
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: Inc
# Role Name: Project Manager
# Score: 7.559043825326259
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: PLC
# Role Name: Content Editor
# Score: 7.559035078894282
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.558348036325797
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 7.558213407198084
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 7.557346021942681
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 7.058466359192537
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: Inc
# Role Name: HR Officer
# Score: 6.56123986204931
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 6.561136961588809
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: PLC
# Role Name: Law Expert
# Score: 6.307361139289412
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: Group
# Role Name: Business Development Manager
# Score: 6.062173979859212
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: Group
# Role Name: Solution Architect
# Score: 5.809702950530786
# --------------------------------------------------
# Applicant name: Tracie
# Project Name: PLC
# Role Name: UX Researcher
# Score: 5.558116342228937
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 8.515675016165387
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: Inc
# Role Name: Risk & Compliance Consultant
# Score: 8.506635113165448
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: Inc
# Role Name: Data Scientist
# Score: 8.015413933423991
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: Group
# Role Name: Security Engineer
# Score: 7.764490505831734
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.761183099711569
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: Inc
# Role Name: Project Manager
# Score: 7.515072577327187
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: PLC
# Role Name: Content Editor
# Score: 7.513682380978563
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 7.512174426058993
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 7.511486764838358
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.511285085626663
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 7.265318686858494
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: Group
# Role Name: Business Development Manager
# Score: 7.017540425519311
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: Group
# Role Name: Solution Architect
# Score: 6.7680023095433075
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: Group
# Role Name: HR Officer
# Score: 6.767649252497917
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 6.76655627615817
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.764412668020168
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: PLC
# Role Name: Law Expert
# Score: 6.261183099711569
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 6.2609775311222045
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: Inc
# Role Name: HR Officer
# Score: 5.767806717961832
# --------------------------------------------------
# Applicant name: Wendy
# Project Name: PLC
# Role Name: UX Researcher
# Score: 5.514931832151238
# --------------------------------------------------
# Applicant name: William
# Project Name: Group
# Role Name: HR Officer
# Score: 8.536657208015244
# --------------------------------------------------
# Applicant name: William
# Project Name: Inc
# Role Name: Project Manager
# Score: 8.533239848894132
# --------------------------------------------------
# Applicant name: William
# Project Name: Group
# Role Name: Security Engineer
# Score: 8.531931588130904
# --------------------------------------------------
# Applicant name: William
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 8.498195023721209
# --------------------------------------------------
# Applicant name: William
# Project Name: Inc
# Role Name: Data Scientist
# Score: 8.033992579461655
# --------------------------------------------------
# Applicant name: William
# Project Name: PLC
# Role Name: Graphic Designer
# Score: 8.033975670925948
# --------------------------------------------------
# Applicant name: William
# Project Name: PLC
# Role Name: Back-End Engineer
# Score: 8.02890056067884
# --------------------------------------------------
# Applicant name: William
# Project Name: PLC
# Role Name: Content Editor
# Score: 8.001076862332523
# --------------------------------------------------
# Applicant name: William
# Project Name: PLC
# Role Name: Law Expert
# Score: 7.747698428073526
# --------------------------------------------------
# Applicant name: William
# Project Name: Inc
# Role Name: HR Officer
# Score: 7.536217693532232
# --------------------------------------------------
# Applicant name: William
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 7.502689668487517
# --------------------------------------------------
# Applicant name: William
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.497634288678192
# --------------------------------------------------
# Applicant name: William
# Project Name: Group
# Role Name: HR Officer
# Score: 7.254141154853368
# --------------------------------------------------
# Applicant name: William
# Project Name: PLC
# Role Name: Financial Advisory Consultant
# Score: 7.03351547597876
# --------------------------------------------------
# Applicant name: William
# Project Name: Inc
# Role Name: Systems Test Engineer
# Score: 7.029017191478144
# --------------------------------------------------
# Applicant name: William
# Project Name: Inc
# Role Name: Networking/Infrastructure Engineer
# Score: 7.028111118044418
# --------------------------------------------------
# Applicant name: William
# Project Name: Inc
# Role Name: Technical Product Manager
# Score: 6.751031920236584
# --------------------------------------------------
# Applicant name: William
# Project Name: PLC
# Role Name: Law Expert
# Score: 6.747698428073526
# --------------------------------------------------
# Applicant name: William
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 6.535442015283006
# --------------------------------------------------
# Applicant name: William
# Project Name: PLC
# Role Name: UX Researcher
# Score: 6.53358942426576
# --------------------------------------------------
# Applicant name: William
# Project Name: Inc
# Role Name: HR Officer
# Score: 6.254862415655098
# --------------------------------------------------
# Applicant name: William
# Project Name: Inc
# Role Name: CX / Business Designer
# Score: 6.248276702888974
# --------------------------------------------------
# Applicant name: William
# Project Name: PLC
# Role Name: UX Researcher
# Score: 6.002724839292759
# --------------------------------------------------
# Applicant name: William
# Project Name: PLC
# Role Name: DevOps Engineer
# Score: 5.753992899842033
# --------------------------------------------------
# Applicant name: William
# Project Name: Group
# Role Name: Business Development Manager
# Score: 5.504230009042761
# --------------------------------------------------
